# %%
# Not necessary to run this script at all, unless you want to update the list of regions

import sys

sys.path.insert(0, "../../")
from region_enricher import RegionEnricher

# %%
region_enricher = RegionEnricher()

region_enricher.process()
# Out:
# 0    POINT (-59.20836 -32.03970)
# 1    POINT (-57.34508 -32.08326)
# 2      POINT (116.38401 1.35406)
# 3      POINT (117.13169 5.34605)
# 4    POINT (-69.63882 -18.48703)
# Name: middle_point, dtype: geometry
# Loading formatted geocoded file...
# Country Dhekelia Sovereign Base Area not found
# Country Gaza Strip not found
# Country West Bank not found
# Country S. Sudan not found
# Country Somaliland not found
# Country Democratic Republic of the Congo not found
# Country Democratic Republic of the Congo not found
# Country Democratic Republic of the Congo not found
# Country Democratic Republic of the Congo not found
# SubdivisionHierarchy(code='NL-SX', country_code='NL', name='Sint Maarten', parent_code=None, type='Country')
# SubdivisionHierarchy(code='BE-WLX', country_code='BE', name='Luxembourg', parent='WAL', parent_code='BE-WAL', type='Province')
# SubdivisionHierarchy(code='LU-LU', country_code='LU', name='Luxembourg', parent_code=None, type='Canton')
# ...
