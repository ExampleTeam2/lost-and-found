# %%
import json
import sys
import os
import cv2
import numpy as np
import concurrent

sys.path.insert(0, '../../')
from data_loader import get_data_to_load, load_json_files, update_data_to_load

MAX_VARIANCE_THRESHOLD = 300
LAPLACIAN_VARIANCE_THRESHOLD = 30
# Only enable if thresholds and filtering didn't change
USE_PREVIOUS = True

files = get_data_to_load(loading_file='../03_mapping/data_list', file_location='../01_enriching/.data/', image_file_location='../../1_data_collection/.data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
files_more_countries = get_data_to_load(loading_file='../03_mapping/more_data_list', file_location='../01_enriching/.data/', image_file_location='../../1_data_collection/.data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
files_non_mapped = get_data_to_load(loading_file='./pre_filtering_data_list', file_location='../01_enriching/.data/', image_file_location='../../1_data_collection/.data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)

original_order = files.copy()
original_order_more_countries = files_more_countries.copy()
original_order_non_mapped = files_non_mapped.copy()

# sort files by file name
files.sort()
files_more_countries.sort()
files_non_mapped.sort()

images = list(filter(lambda x: x.endswith('.png'), files))
images_more_countries = list(filter(lambda x: x.endswith('.png'), files_more_countries))
images_non_mapped = list(filter(lambda x: x.endswith('.png'), files_non_mapped))
jsons = list(filter(lambda x: x.endswith('.json'), files))
jsons_more_countries = list(filter(lambda x: x.endswith('.json'), files_more_countries))
jsons_non_mapped = list(filter(lambda x: x.endswith('.json'), files_non_mapped))

print(len(images))
print(len(images_more_countries))
print(len(images_non_mapped))

filtered_files = []
filtered_files_more_countries = []
filtered_files_non_mapped = []

variance_map = {}
variance_map_more_countries = {}
variance_map_non_mapped = {}

laplacian_variance_map = {}
laplacian_variance_map_more_countries = {}
laplacian_variance_map_non_mapped = {}

# pre load previous variance data if available
if USE_PREVIOUS:
  if os.path.exists('variance_map'):
    with open('variance_map', 'r', encoding='utf8') as f:
      variance_map = json.load(f)
  if os.path.exists('variance_map_more'):
    with open('variance_map_more', 'r', encoding='utf8') as f:
      variance_map_more_countries = json.load(f)
  if os.path.exists('variance_map_non_mapped'):
    with open('variance_map_non_mapped', 'r', encoding='utf8') as f:
      variance_map_non_mapped = json.load(f)
  if os.path.exists('laplacian_variance_map'):
    with open('laplacian_variance_map', 'r', encoding='utf8') as f:
      laplacian_variance_map = json.load(f)
  if os.path.exists('laplacian_variance_map_more'):
    with open('laplacian_variance_map_more', 'r', encoding='utf8') as f:
      laplacian_variance_map_more_countries = json.load(f)
  if os.path.exists('laplacian_variance_map_non_mapped'):
    with open('laplacian_variance_map_non_mapped', 'r', encoding='utf8') as f:
      laplacian_variance_map_non_mapped = json.load(f)

# kernel to detect blurry images
laplacian_kernel = np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]])

def process_image(image_path, json_path):
  image = cv2.imread(image_path)
  try:
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  except cv2.error as e:
    print("Error reading image:", os.path.basename(image_path))
    print(e)
    return None
  
  variance_colors = np.var(image, axis=(0, 1))
  
  max_variance = np.max(variance_colors)
  
  # get variance to detect blurry images, use grayscale image
  gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  laplacian = cv2.filter2D(gray, cv2.CV_32F, laplacian_kernel)
  
  laplacian_variance = float(np.var(laplacian))
  
  return [image_path, json_path, max_variance, laplacian_variance]

def process_all(current_images, current_jsons, current_variance_map, current_laplacian_variance_map, current_filtered_files):
  def process_image_with_cache(image_path, json_path):
    image_basename = os.path.basename(image_path)
    
    if image_basename in current_variance_map:
      max_variance = current_variance_map[image_basename]
    else:
      max_variance = None
      
    if image_basename in current_laplacian_variance_map:
      laplacian_variance = current_laplacian_variance_map[image_basename]
    else:
      laplacian_variance = None
      
    if max_variance is None or laplacian_variance is None:
      result = process_image(image_path, json_path)
      if result is not None:
        image_path, json_path, max_variance, laplacian_variance = result
      else:
        return None
      
    return image_path, json_path, max_variance, laplacian_variance
    
  
  with concurrent.futures.ThreadPoolExecutor(max_workers=16) as executor:
    results = [executor.submit(process_image_with_cache, image_path, json_path) for image_path, json_path in zip(current_images, current_jsons)]
    
    for result in results:
      if result.result() is not None:
        image_path, json_path, max_variance, laplacian_variance = result.result()
        
        image_basename = os.path.basename(image_path)
        json_basename = os.path.basename(json_path)
        
        current_variance_map[image_basename] = max_variance
        current_laplacian_variance_map[image_basename] = laplacian_variance
        
        if max_variance > MAX_VARIANCE_THRESHOLD:
          if laplacian_variance > LAPLACIAN_VARIANCE_THRESHOLD:
            current_filtered_files.append(image_path)
            current_filtered_files.append(json_path)
          else:
            print("Too low laplacian variance:", image_basename)
            print("Corresponding result:", json_basename)
            print("Laplacian variance:", laplacian_variance)
        else:
          print("Too low max RGB variance:", image_basename)
          print("Corresponding result:", json_basename)
          print("Max RGB variance:", max_variance)
          
    current_filtered_images = list(filter(lambda x: x.endswith('.png'), current_filtered_files))
    
    return current_filtered_files, current_filtered_images
        
filtered_files, filtered_images = process_all(images, jsons, variance_map, laplacian_variance_map, filtered_files)

filtered_files_more_countries, filtered_images_more_countries = process_all(images_more_countries, jsons_more_countries, variance_map_more_countries, laplacian_variance_map_more_countries, filtered_files_more_countries)

filtered_files_non_mapped, filtered_images_non_mapped = process_all(images_non_mapped, jsons_non_mapped, variance_map_non_mapped, laplacian_variance_map_non_mapped, filtered_files_non_mapped)
      
print(len(filtered_images))
print(len(filtered_images_more_countries))
print(len(filtered_images_non_mapped))

# remove files from map that are not in the filtered list
filtered_files_basenames_set = set(map(os.path.basename, filtered_files))
filtered_files_more_countries_basenames_set = set(map(os.path.basename, filtered_files_more_countries))
filtered_files_non_mapped_basenames_set = set(map(os.path.basename, filtered_files_non_mapped))

variance_map = {k: v for k, v in variance_map.items() if k in filtered_files_basenames_set}
variance_map_more_countries = {k: v for k, v in variance_map_more_countries.items() if k in filtered_files_more_countries_basenames_set}
variance_map_non_mapped = {k: v for k, v in variance_map_non_mapped.items() if k in filtered_files_non_mapped_basenames_set}
laplacian_variance_map = {k: v for k, v in laplacian_variance_map.items() if k in filtered_files_basenames_set}
laplacian_variance_map_more_countries = {k: v for k, v in laplacian_variance_map_more_countries.items() if k in filtered_files_more_countries_basenames_set}
laplacian_variance_map_non_mapped = {k: v for k, v in laplacian_variance_map_non_mapped.items() if k in filtered_files_non_mapped_basenames_set}

with open('variance_map', 'w', encoding='utf8') as f:
    json.dump(variance_map, f, ensure_ascii=False)
    
with open('variance_map_more', 'w', encoding='utf8') as f:
    json.dump(variance_map_more_countries, f, ensure_ascii=False)
    
with open('variance_map_non_mapped', 'w', encoding='utf8') as f:
    json.dump(variance_map_non_mapped, f, ensure_ascii=False)
    
with open('laplacian_variance_map', 'w', encoding='utf8') as f:
    json.dump(laplacian_variance_map, f, ensure_ascii=False)
    
with open('laplacian_variance_map_more', 'w', encoding='utf8') as f:
    json.dump(laplacian_variance_map_more_countries, f, ensure_ascii=False)
    
with open('laplacian_variance_map_non_mapped', 'w', encoding='utf8') as f:
    json.dump(laplacian_variance_map_non_mapped, f, ensure_ascii=False)
    
current_files = filtered_files.copy()
current_files_more_countries = filtered_files_more_countries.copy()
current_files_non_mapped = filtered_files_non_mapped.copy()

images = list(filter(lambda x: x.endswith('.png'), current_files))
images_more_countries = list(filter(lambda x: x.endswith('.png'), current_files_more_countries))
images_non_mapped = list(filter(lambda x: x.endswith('.png'), current_files_non_mapped))
jsons = list(filter(lambda x: x.endswith('.json'), current_files))
jsons_more_countries = list(filter(lambda x: x.endswith('.json'), current_files_more_countries))
jsons_non_mapped = list(filter(lambda x: x.endswith('.json'), current_files_non_mapped))

jsons_data = load_json_files(jsons, allow_err=True)
jsons_data_more_countries = load_json_files(jsons_more_countries, allow_err=True)
jsons_data_non_mapped = load_json_files(jsons_non_mapped, allow_err=True)

def remove_duplicates(current_images, current_jsons, current_jsons_data):
  current_filtered_files = []

  current_duplicate_locations = 0

  previous_locations = set()

  for image_path, json_path, json_data in zip(current_images, current_jsons, current_jsons_data):
    if json_data is None:
      continue
    # if they have the same coordinates, then they are the same location, only use the first
    str_coords = str(json_data['coordinates'])
    if str_coords in previous_locations:
      current_duplicate_locations += 1
      continue
    else:
      previous_locations.add(str_coords)
      current_filtered_files.append(image_path)
      current_filtered_files.append(json_path)
      
  current_filtered_images = list(filter(lambda x: x.endswith('.png'), current_filtered_files))
      
  return current_filtered_files, current_filtered_images, current_duplicate_locations

filtered_files, filtered_images, duplicate_locations = remove_duplicates(images, jsons, jsons_data)

print("Duplicate locations:", duplicate_locations)

filtered_files_more_countries, filtered_images_more_countries, duplicate_locations_more_countries = remove_duplicates(images_more_countries, jsons_more_countries, jsons_data_more_countries)

print("Duplicate locations more countries:", duplicate_locations_more_countries)

filtered_files_non_mapped, filtered_images_non_mapped, duplicate_locations_non_mapped = remove_duplicates(images_non_mapped, jsons_non_mapped, jsons_data_non_mapped)

print("Duplicate locations non mapped:", duplicate_locations_non_mapped)

print(len(filtered_images))
print(len(filtered_images_more_countries))
print(len(filtered_images_non_mapped))

filtered_files_set = set(filtered_files)
filtered_files_more_countries_set = set(filtered_files_more_countries)
filtered_files_non_mapped_set = set(filtered_files_non_mapped)
    
# Sort back to original order (some files were removed)
filtered_files = [file for file in original_order if file in filtered_files_set]
filtered_files_more_countries = [file for file in original_order_more_countries if file in filtered_files_more_countries_set]
filtered_files_non_mapped = [file for file in original_order_non_mapped if file in filtered_files_non_mapped_set]

update_data_to_load(filtered_files, old_loading_file='../03_mapping/data_list', file_location='../01_enriching/data/', image_file_location='../../1_data_collection/data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
update_data_to_load(filtered_files_more_countries, new_loading_file='./updated_data_list_more', old_loading_file='../03_mapping/more_data_list', file_location='../01_enriching/data/', image_file_location='../../1_data_collection/data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
update_data_to_load(filtered_files_non_mapped, new_loading_file='./updated_data_list_non_mapped', old_loading_file='./pre_filtering_data_list', file_location='../01_enriching/data/', image_file_location='../../1_data_collection/data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
# Out:
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Filtering out unpaired files
# Filtered out 27805 unpaired files
# Relevant files: 677876
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Filtering out unpaired files
# Filtered out 27805 unpaired files
# Relevant files: 677876
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Filtering out unpaired files
# Filtered out 27805 unpaired files
# Relevant files: 677876
# 95153
# 82473
# 338938
# libpng error: Read Error
# Error reading image: geoguessr_location_singleplayer_03MrvgM0hjFtwQVB_3.png
# OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
# Too low max RGB variance: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_0.png
# Corresponding result: geoguessr_result_singleplayer_00RUSiKypPGLhMjI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_04aIMEDoIsolXMPG_0.png
# Corresponding result: geoguessr_result_singleplayer_04aIMEDoIsolXMPG_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_08LAHDNXMTUTEF8o_0.png
# Corresponding result: geoguessr_result_singleplayer_08LAHDNXMTUTEF8o_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0E2f8UWXhDx2ABZP_0.png
# Corresponding result: geoguessr_result_singleplayer_0E2f8UWXhDx2ABZP_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0FWcmlORR9hPRjcS_0.png
# Corresponding result: geoguessr_result_singleplayer_0FWcmlORR9hPRjcS_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0J6s8ND11fhb3IqY_0.png
# Corresponding result: geoguessr_result_singleplayer_0J6s8ND11fhb3IqY_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0M8pcOqBtGPWdghb_0.png
# Corresponding result: geoguessr_result_singleplayer_0M8pcOqBtGPWdghb_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0OKIKa6BvZ7SCYIh_0.png
# Corresponding result: geoguessr_result_singleplayer_0OKIKa6BvZ7SCYIh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0ORjQsJIoYvpalOO_0.png
# Corresponding result: geoguessr_result_singleplayer_0ORjQsJIoYvpalOO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0QCH7vb2774ZLKy8_0.png
# Corresponding result: geoguessr_result_singleplayer_0QCH7vb2774ZLKy8_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0YBPvcKLUxgyvYDg_0.png
# Corresponding result: geoguessr_result_singleplayer_0YBPvcKLUxgyvYDg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0cZnbBk46V6mYOYU_4.png
# Corresponding result: geoguessr_result_singleplayer_0cZnbBk46V6mYOYU_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0fPz2yJE6Od1b2xC_1.png
# Corresponding result: geoguessr_result_singleplayer_0fPz2yJE6Od1b2xC_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0fPz2yJE6Od1b2xC_2.png
# Corresponding result: geoguessr_result_singleplayer_0fPz2yJE6Od1b2xC_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0ittmDsjc2sa5sKW_0.png
# Corresponding result: geoguessr_result_singleplayer_0ittmDsjc2sa5sKW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0lNmRppDY80alSFw_0.png
# Corresponding result: geoguessr_result_singleplayer_0lNmRppDY80alSFw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0pw106oHdiX0IIql_0.png
# Corresponding result: geoguessr_result_singleplayer_0pw106oHdiX0IIql_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0sAD83ZLU3U1Qm73_3.png
# Corresponding result: geoguessr_result_singleplayer_0sAD83ZLU3U1Qm73_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0sYBLn7GBNNBusO0_0.png
# Corresponding result: geoguessr_result_singleplayer_0sYBLn7GBNNBusO0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0siWbopulukLjlHa_0.png
# Corresponding result: geoguessr_result_singleplayer_0siWbopulukLjlHa_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_0uA0ZxmbcLWmXwgQ_0.png
# Corresponding result: geoguessr_result_singleplayer_0uA0ZxmbcLWmXwgQ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_13rAWwKrncMulI3l_0.png
# Corresponding result: geoguessr_result_singleplayer_13rAWwKrncMulI3l_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_163j1pGtCAeDhHWe_0.png
# Corresponding result: geoguessr_result_singleplayer_163j1pGtCAeDhHWe_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_17NucLXEjJ7duAOJ_2.png
# Corresponding result: geoguessr_result_singleplayer_17NucLXEjJ7duAOJ_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1AP4c3opAgk2E4OF_0.png
# Corresponding result: geoguessr_result_singleplayer_1AP4c3opAgk2E4OF_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1BhmkNjsXSetbXEg_0.png
# Corresponding result: geoguessr_result_singleplayer_1BhmkNjsXSetbXEg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1DJxxJcLPaUBFszS_0.png
# Corresponding result: geoguessr_result_singleplayer_1DJxxJcLPaUBFszS_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1H2AzVYoLV5brKrD_0.png
# Corresponding result: geoguessr_result_singleplayer_1H2AzVYoLV5brKrD_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1L4QgZKN4Vo1ZgVw_4.png
# Corresponding result: geoguessr_result_singleplayer_1L4QgZKN4Vo1ZgVw_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1LHIvex1lkV5xqBD_0.png
# Corresponding result: geoguessr_result_singleplayer_1LHIvex1lkV5xqBD_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1LmKcoQyjnD7AgM0_0.png
# Corresponding result: geoguessr_result_singleplayer_1LmKcoQyjnD7AgM0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1Pzl6vJaBKSWaDRg_0.png
# Corresponding result: geoguessr_result_singleplayer_1Pzl6vJaBKSWaDRg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1e7A1MhgWZOYxwQo_0.png
# Corresponding result: geoguessr_result_singleplayer_1e7A1MhgWZOYxwQo_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1gWFND6S2vOY65BW_3.png
# Corresponding result: geoguessr_result_singleplayer_1gWFND6S2vOY65BW_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1hbUrYinJazyxcAX_0.png
# Corresponding result: geoguessr_result_singleplayer_1hbUrYinJazyxcAX_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1jhquqTIj7cwuh7e_0.png
# Corresponding result: geoguessr_result_singleplayer_1jhquqTIj7cwuh7e_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1l10xdaTFPSLFJjM_0.png
# Corresponding result: geoguessr_result_singleplayer_1l10xdaTFPSLFJjM_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1l7RWtYOx0RN9EZC_0.png
# Corresponding result: geoguessr_result_singleplayer_1l7RWtYOx0RN9EZC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1lfizgCPPwbmnCkM_0.png
# Corresponding result: geoguessr_result_singleplayer_1lfizgCPPwbmnCkM_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1rjS1uZqdWLHO7Ld_0.png
# Corresponding result: geoguessr_result_singleplayer_1rjS1uZqdWLHO7Ld_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_1upIW2k4s7el3yPP_4.png
# Corresponding result: geoguessr_result_singleplayer_1upIW2k4s7el3yPP_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_23U8tpYBNJ39eN0z_0.png
# Corresponding result: geoguessr_result_singleplayer_23U8tpYBNJ39eN0z_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_28klsSsTUuJByh6s_0.png
# Corresponding result: geoguessr_result_singleplayer_28klsSsTUuJByh6s_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2D58pUdFRbVeXkxK_0.png
# Corresponding result: geoguessr_result_singleplayer_2D58pUdFRbVeXkxK_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2NN2757L9VbeljnO_0.png
# Corresponding result: geoguessr_result_singleplayer_2NN2757L9VbeljnO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2PkUaqKwZ72nbV7F_0.png
# Corresponding result: geoguessr_result_singleplayer_2PkUaqKwZ72nbV7F_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2QSsH9SQxCdgceZn_0.png
# Corresponding result: geoguessr_result_singleplayer_2QSsH9SQxCdgceZn_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2W1nFIJfUZY3FEbg_0.png
# Corresponding result: geoguessr_result_singleplayer_2W1nFIJfUZY3FEbg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2hddgfrE5xFNPMqR_0.png
# Corresponding result: geoguessr_result_singleplayer_2hddgfrE5xFNPMqR_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2kyPq5w91DL0OyZP_2.png
# Corresponding result: geoguessr_result_singleplayer_2kyPq5w91DL0OyZP_2.json
# Max RGB variance: 62.57306631462696
# Too low max RGB variance: geoguessr_location_singleplayer_2n2jAGvEF6Bulue6_0.png
# Corresponding result: geoguessr_result_singleplayer_2n2jAGvEF6Bulue6_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2rcHHEjDpk8FQA0H_3.png
# Corresponding result: geoguessr_result_singleplayer_2rcHHEjDpk8FQA0H_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2sDy5WqaokwT7WQN_0.png
# Corresponding result: geoguessr_result_singleplayer_2sDy5WqaokwT7WQN_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2tysrXSrUHkQcZb0_0.png
# Corresponding result: geoguessr_result_singleplayer_2tysrXSrUHkQcZb0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2vuye4T2oUO7Qx3J_0.png
# Corresponding result: geoguessr_result_singleplayer_2vuye4T2oUO7Qx3J_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_2wp25Rwc7g20gqis_0.png
# Corresponding result: geoguessr_result_singleplayer_2wp25Rwc7g20gqis_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3129WSrk5Z1QUDFY_0.png
# Corresponding result: geoguessr_result_singleplayer_3129WSrk5Z1QUDFY_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_34RlmecZqYi7scJz_0.png
# Corresponding result: geoguessr_result_singleplayer_34RlmecZqYi7scJz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_34moNSNYn5ItGrhn_0.png
# Corresponding result: geoguessr_result_singleplayer_34moNSNYn5ItGrhn_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_383SvxshBSQI25Uz_4.png
# Corresponding result: geoguessr_result_singleplayer_383SvxshBSQI25Uz_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_39RqDe8wE5AgyA3o_0.png
# Corresponding result: geoguessr_result_singleplayer_39RqDe8wE5AgyA3o_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_39iBoqg5Tenl5IAM_1.png
# Corresponding result: geoguessr_result_singleplayer_39iBoqg5Tenl5IAM_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3Dym0joIaI8UWK3X_0.png
# Corresponding result: geoguessr_result_singleplayer_3Dym0joIaI8UWK3X_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3EzPfTPbePbojIhU_0.png
# Corresponding result: geoguessr_result_singleplayer_3EzPfTPbePbojIhU_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3FgNYkBJHXG02osA_0.png
# Corresponding result: geoguessr_result_singleplayer_3FgNYkBJHXG02osA_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3FrJ2YDAylBKiyOP_0.png
# Corresponding result: geoguessr_result_singleplayer_3FrJ2YDAylBKiyOP_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3Hj4o8CiDN4yh6j9_0.png
# Corresponding result: geoguessr_result_singleplayer_3Hj4o8CiDN4yh6j9_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3KZWFrVUuSlT5IzQ_0.png
# Corresponding result: geoguessr_result_singleplayer_3KZWFrVUuSlT5IzQ_0.json
# Max RGB variance: 0.0
# Too low laplacian variance: geoguessr_location_singleplayer_3KiSNrKw6y7j0y4O_1.png
# Corresponding result: geoguessr_result_singleplayer_3KiSNrKw6y7j0y4O_1.json
# Laplacian variance: 9.224251747131348
# Too low max RGB variance: geoguessr_location_singleplayer_3LRLet6cgCw8aQbs_0.png
# Corresponding result: geoguessr_result_singleplayer_3LRLet6cgCw8aQbs_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3Ud3VAFSJHjiUILC_0.png
# Corresponding result: geoguessr_result_singleplayer_3Ud3VAFSJHjiUILC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3c0QTa2R3NGafSsl_0.png
# Corresponding result: geoguessr_result_singleplayer_3c0QTa2R3NGafSsl_0.json
# Max RGB variance: 86.70733905978553
# Too low max RGB variance: geoguessr_location_singleplayer_3cIOrULzzKHYnYu7_3.png
# Corresponding result: geoguessr_result_singleplayer_3cIOrULzzKHYnYu7_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3dURF4Kx8HwZVAp4_0.png
# Corresponding result: geoguessr_result_singleplayer_3dURF4Kx8HwZVAp4_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3fUS43uAIYgtCPEn_0.png
# Corresponding result: geoguessr_result_singleplayer_3fUS43uAIYgtCPEn_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3khO6bHYJl5p38bi_0.png
# Corresponding result: geoguessr_result_singleplayer_3khO6bHYJl5p38bi_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3ozRBTYafWlHsXA4_0.png
# Corresponding result: geoguessr_result_singleplayer_3ozRBTYafWlHsXA4_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3q1bNVSzatJCBRq0_0.png
# Corresponding result: geoguessr_result_singleplayer_3q1bNVSzatJCBRq0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3rifgKr4C5rR1IWe_0.png
# Corresponding result: geoguessr_result_singleplayer_3rifgKr4C5rR1IWe_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3vS47L3I0n9oH7bO_0.png
# Corresponding result: geoguessr_result_singleplayer_3vS47L3I0n9oH7bO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3wGYsQhcwP8C5Uaw_2.png
# Corresponding result: geoguessr_result_singleplayer_3wGYsQhcwP8C5Uaw_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_3ytF7afVqfs0wtMX_3.png
# Corresponding result: geoguessr_result_singleplayer_3ytF7afVqfs0wtMX_3.json
# Max RGB variance: 31.108286009550426
# Too low max RGB variance: geoguessr_location_singleplayer_40hD9NZZl8UAGnqX_0.png
# Corresponding result: geoguessr_result_singleplayer_40hD9NZZl8UAGnqX_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_45LUKuelngsn20CK_0.png
# Corresponding result: geoguessr_result_singleplayer_45LUKuelngsn20CK_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_48SEvwwn0awnU7yC_0.png
# Corresponding result: geoguessr_result_singleplayer_48SEvwwn0awnU7yC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4BiG59ozEC2xTa2v_0.png
# Corresponding result: geoguessr_result_singleplayer_4BiG59ozEC2xTa2v_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4HQcyVVcPkybaJF7_1.png
# Corresponding result: geoguessr_result_singleplayer_4HQcyVVcPkybaJF7_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4J8pyhGaXO6Fer7R_0.png
# Corresponding result: geoguessr_result_singleplayer_4J8pyhGaXO6Fer7R_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4KI06eXpOyPuJQ9Z_0.png
# Corresponding result: geoguessr_result_singleplayer_4KI06eXpOyPuJQ9Z_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4NfK8UBbVIzsuXxP_4.png
# Corresponding result: geoguessr_result_singleplayer_4NfK8UBbVIzsuXxP_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4Qo2r4LBcU9tQJHm_0.png
# Corresponding result: geoguessr_result_singleplayer_4Qo2r4LBcU9tQJHm_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4SXoM2ktZlftLWaK_0.png
# Corresponding result: geoguessr_result_singleplayer_4SXoM2ktZlftLWaK_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4TvkpwPgnHi4jpXa_0.png
# Corresponding result: geoguessr_result_singleplayer_4TvkpwPgnHi4jpXa_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4UqZGeGDAXQzw4TM_0.png
# Corresponding result: geoguessr_result_singleplayer_4UqZGeGDAXQzw4TM_0.json
# Max RGB variance: 244.27524391280633
# Too low max RGB variance: geoguessr_location_singleplayer_4Yww1Kwa0CvXd9cg_0.png
# Corresponding result: geoguessr_result_singleplayer_4Yww1Kwa0CvXd9cg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4a7UfnqESS8vcuav_0.png
# Corresponding result: geoguessr_result_singleplayer_4a7UfnqESS8vcuav_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4br9cctrRfnatkly_0.png
# Corresponding result: geoguessr_result_singleplayer_4br9cctrRfnatkly_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4gBcbFHSg0i8OZgf_1.png
# Corresponding result: geoguessr_result_singleplayer_4gBcbFHSg0i8OZgf_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4gyjd1cgZiwPb13W_0.png
# Corresponding result: geoguessr_result_singleplayer_4gyjd1cgZiwPb13W_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4iwcDmuZAaTfzaIP_0.png
# Corresponding result: geoguessr_result_singleplayer_4iwcDmuZAaTfzaIP_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4kIpgiHbDehQYkGp_0.png
# Corresponding result: geoguessr_result_singleplayer_4kIpgiHbDehQYkGp_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4m0vbwlyo3Xel4Xk_0.png
# Corresponding result: geoguessr_result_singleplayer_4m0vbwlyo3Xel4Xk_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4m8Upkw7IMq6a9UA_0.png
# Corresponding result: geoguessr_result_singleplayer_4m8Upkw7IMq6a9UA_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4nyDrVJPQteIBzXe_3.png
# Corresponding result: geoguessr_result_singleplayer_4nyDrVJPQteIBzXe_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4r2ZGNr4rxBj0gBT_0.png
# Corresponding result: geoguessr_result_singleplayer_4r2ZGNr4rxBj0gBT_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4rezhTW9OUYsGThr_0.png
# Corresponding result: geoguessr_result_singleplayer_4rezhTW9OUYsGThr_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_4tzEuPQMnpWml2t7_0.png
# Corresponding result: geoguessr_result_singleplayer_4tzEuPQMnpWml2t7_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_54mT2FZQPHFyUfP1_0.png
# Corresponding result: geoguessr_result_singleplayer_54mT2FZQPHFyUfP1_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_57BmTxgfA8L69ZIU_0.png
# Corresponding result: geoguessr_result_singleplayer_57BmTxgfA8L69ZIU_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5C71qf1OTq68dUe5_0.png
# Corresponding result: geoguessr_result_singleplayer_5C71qf1OTq68dUe5_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5CEysQg6HCMXa7HN_0.png
# Corresponding result: geoguessr_result_singleplayer_5CEysQg6HCMXa7HN_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5F1CAcGyDfs6la2b_0.png
# Corresponding result: geoguessr_result_singleplayer_5F1CAcGyDfs6la2b_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5GOpBS6GEqoc9rWn_0.png
# Corresponding result: geoguessr_result_singleplayer_5GOpBS6GEqoc9rWn_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5KzRY4AzTrR6laNI_0.png
# Corresponding result: geoguessr_result_singleplayer_5KzRY4AzTrR6laNI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5LOVA7sTjsALEFXy_0.png
# Corresponding result: geoguessr_result_singleplayer_5LOVA7sTjsALEFXy_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5Nrx7EQ28qAqMrzi_0.png
# Corresponding result: geoguessr_result_singleplayer_5Nrx7EQ28qAqMrzi_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5Oc8f62XawyodP9c_0.png
# Corresponding result: geoguessr_result_singleplayer_5Oc8f62XawyodP9c_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5Vgzks7inJuVH5lh_0.png
# Corresponding result: geoguessr_result_singleplayer_5Vgzks7inJuVH5lh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5bDS9kV8xRugpEMm_0.png
# Corresponding result: geoguessr_result_singleplayer_5bDS9kV8xRugpEMm_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5cPaoDpehjzVq3uf_0.png
# Corresponding result: geoguessr_result_singleplayer_5cPaoDpehjzVq3uf_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5jWjiuKqZPRfPc42_0.png
# Corresponding result: geoguessr_result_singleplayer_5jWjiuKqZPRfPc42_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5lKZeuxgTWtsdNeI_0.png
# Corresponding result: geoguessr_result_singleplayer_5lKZeuxgTWtsdNeI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5nK4xwNsrtngrfQ8_0.png
# Corresponding result: geoguessr_result_singleplayer_5nK4xwNsrtngrfQ8_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5ojLWdFmkLPyZnGL_0.png
# Corresponding result: geoguessr_result_singleplayer_5ojLWdFmkLPyZnGL_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5rpekcwFl5gA251T_2.png
# Corresponding result: geoguessr_result_singleplayer_5rpekcwFl5gA251T_2.json
# Max RGB variance: 12.105062209441598
# Too low max RGB variance: geoguessr_location_singleplayer_5s5kvWkBIUMuq8YL_0.png
# Corresponding result: geoguessr_result_singleplayer_5s5kvWkBIUMuq8YL_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5vCYjtI23vaFHv9i_0.png
# Corresponding result: geoguessr_result_singleplayer_5vCYjtI23vaFHv9i_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_5zabKp6VGVnh5Qi0_2.png
# Corresponding result: geoguessr_result_singleplayer_5zabKp6VGVnh5Qi0_2.json
# Max RGB variance: 214.00591984818988
# Too low max RGB variance: geoguessr_location_singleplayer_63JO5X7u4i7hOM2A_0.png
# Corresponding result: geoguessr_result_singleplayer_63JO5X7u4i7hOM2A_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_66ePzjQCgnBfFAwh_0.png
# Corresponding result: geoguessr_result_singleplayer_66ePzjQCgnBfFAwh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_69BzOjchAevdv7sY_4.png
# Corresponding result: geoguessr_result_singleplayer_69BzOjchAevdv7sY_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6EoNWjAIz2LQEx8m_0.png
# Corresponding result: geoguessr_result_singleplayer_6EoNWjAIz2LQEx8m_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6HlyTyfIREiI8Ac3_0.png
# Corresponding result: geoguessr_result_singleplayer_6HlyTyfIREiI8Ac3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6Jg8vMbjSlwdUbt4_0.png
# Corresponding result: geoguessr_result_singleplayer_6Jg8vMbjSlwdUbt4_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6Syfonb8hKOeGGz6_0.png
# Corresponding result: geoguessr_result_singleplayer_6Syfonb8hKOeGGz6_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6Z4eSoIlfrr4EuOb_0.png
# Corresponding result: geoguessr_result_singleplayer_6Z4eSoIlfrr4EuOb_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6ZCxpidoWSaSTgwp_2.png
# Corresponding result: geoguessr_result_singleplayer_6ZCxpidoWSaSTgwp_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6aZjavS4RdkjGXad_0.png
# Corresponding result: geoguessr_result_singleplayer_6aZjavS4RdkjGXad_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6azF314OroWpPtAS_0.png
# Corresponding result: geoguessr_result_singleplayer_6azF314OroWpPtAS_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6fBUH1Cs1LyztLuy_0.png
# Corresponding result: geoguessr_result_singleplayer_6fBUH1Cs1LyztLuy_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6fPjbVfBEIz75duW_0.png
# Corresponding result: geoguessr_result_singleplayer_6fPjbVfBEIz75duW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6kx1WUM6h7ekqS5r_0.png
# Corresponding result: geoguessr_result_singleplayer_6kx1WUM6h7ekqS5r_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6oVlPz6PzGdqhdsH_0.png
# Corresponding result: geoguessr_result_singleplayer_6oVlPz6PzGdqhdsH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6rjTlMRqlliWA0WO_0.png
# Corresponding result: geoguessr_result_singleplayer_6rjTlMRqlliWA0WO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6svYbDY9WVZvQlXq_1.png
# Corresponding result: geoguessr_result_singleplayer_6svYbDY9WVZvQlXq_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_6xLszTmmmbfht3oh_0.png
# Corresponding result: geoguessr_result_singleplayer_6xLszTmmmbfht3oh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_72vuequa9vHK4WWw_0.png
# Corresponding result: geoguessr_result_singleplayer_72vuequa9vHK4WWw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_756wKpT16kZLaVcO_0.png
# Corresponding result: geoguessr_result_singleplayer_756wKpT16kZLaVcO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_76naEYE5PhMhwL3O_0.png
# Corresponding result: geoguessr_result_singleplayer_76naEYE5PhMhwL3O_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_78TzCueVFOByxIqU_0.png
# Corresponding result: geoguessr_result_singleplayer_78TzCueVFOByxIqU_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_78xhDJOvuV78hRWe_0.png
# Corresponding result: geoguessr_result_singleplayer_78xhDJOvuV78hRWe_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7DVXckFpAlj7y5fz_0.png
# Corresponding result: geoguessr_result_singleplayer_7DVXckFpAlj7y5fz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7JPHbdzA8e12gMBu_2.png
# Corresponding result: geoguessr_result_singleplayer_7JPHbdzA8e12gMBu_2.json
# Max RGB variance: 46.308277734368836
# Too low max RGB variance: geoguessr_location_singleplayer_7JslYa1xNgA1vhg1_0.png
# Corresponding result: geoguessr_result_singleplayer_7JslYa1xNgA1vhg1_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7RLDDRUnuq0FbdCA_0.png
# Corresponding result: geoguessr_result_singleplayer_7RLDDRUnuq0FbdCA_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7UTIuY6upRwALNmc_0.png
# Corresponding result: geoguessr_result_singleplayer_7UTIuY6upRwALNmc_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7Uk8iGJkuc2YfnI0_4.png
# Corresponding result: geoguessr_result_singleplayer_7Uk8iGJkuc2YfnI0_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7YWJyNFTfos9Wh95_3.png
# Corresponding result: geoguessr_result_singleplayer_7YWJyNFTfos9Wh95_3.json
# Max RGB variance: 290.6425442681109
# Too low max RGB variance: geoguessr_location_singleplayer_7ZHWmmuVIqYIjc2f_0.png
# Corresponding result: geoguessr_result_singleplayer_7ZHWmmuVIqYIjc2f_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7bvtOKbH1texceuv_0.png
# Corresponding result: geoguessr_result_singleplayer_7bvtOKbH1texceuv_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7eQiCm3DszFCCo8Q_0.png
# Corresponding result: geoguessr_result_singleplayer_7eQiCm3DszFCCo8Q_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7lB4OXCDazNXbGXz_0.png
# Corresponding result: geoguessr_result_singleplayer_7lB4OXCDazNXbGXz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7lJLgWElKbZSaZZs_2.png
# Corresponding result: geoguessr_result_singleplayer_7lJLgWElKbZSaZZs_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7qN05pBh1hgagnYc_2.png
# Corresponding result: geoguessr_result_singleplayer_7qN05pBh1hgagnYc_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7rcCV1bXsap5lECz_0.png
# Corresponding result: geoguessr_result_singleplayer_7rcCV1bXsap5lECz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7s2iK9dP9H5ONKGv_4.png
# Corresponding result: geoguessr_result_singleplayer_7s2iK9dP9H5ONKGv_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_7sAtic49xOwDGwJI_0.png
# Corresponding result: geoguessr_result_singleplayer_7sAtic49xOwDGwJI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_85FmM3AEAOVmRKjb_0.png
# Corresponding result: geoguessr_result_singleplayer_85FmM3AEAOVmRKjb_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_88DGueES3HVgEEOK_0.png
# Corresponding result: geoguessr_result_singleplayer_88DGueES3HVgEEOK_0.json
# Max RGB variance: 111.09428464505358
# Too low max RGB variance: geoguessr_location_singleplayer_8E1rR8EeP4ja7p45_0.png
# Corresponding result: geoguessr_result_singleplayer_8E1rR8EeP4ja7p45_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8Eq5LKazNpp9avom_0.png
# Corresponding result: geoguessr_result_singleplayer_8Eq5LKazNpp9avom_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8FpMAxLOWekSFgo3_2.png
# Corresponding result: geoguessr_result_singleplayer_8FpMAxLOWekSFgo3_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8FyCaBdHfJWL2dkk_1.png
# Corresponding result: geoguessr_result_singleplayer_8FyCaBdHfJWL2dkk_1.json
# Max RGB variance: 164.2340378858243
# Too low max RGB variance: geoguessr_location_singleplayer_8GP2YbTd4oAfJnlF_0.png
# Corresponding result: geoguessr_result_singleplayer_8GP2YbTd4oAfJnlF_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8SU9ihIhDUzy2nXH_0.png
# Corresponding result: geoguessr_result_singleplayer_8SU9ihIhDUzy2nXH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8UMCzosvgejMniCO_0.png
# Corresponding result: geoguessr_result_singleplayer_8UMCzosvgejMniCO_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8W69vstKCBmAlnqs_4.png
# Corresponding result: geoguessr_result_singleplayer_8W69vstKCBmAlnqs_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8YfpXywmutrZENxE_3.png
# Corresponding result: geoguessr_result_singleplayer_8YfpXywmutrZENxE_3.json
# Max RGB variance: 143.10172957054877
# Too low max RGB variance: geoguessr_location_singleplayer_8ZBbcIvUBimAiybh_0.png
# Corresponding result: geoguessr_result_singleplayer_8ZBbcIvUBimAiybh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8ZG76Ldpb6yyt4Es_0.png
# Corresponding result: geoguessr_result_singleplayer_8ZG76Ldpb6yyt4Es_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8ay0BGnhrEK126aj_4.png
# Corresponding result: geoguessr_result_singleplayer_8ay0BGnhrEK126aj_4.json
# Max RGB variance: 140.74844521491764
# Too low max RGB variance: geoguessr_location_singleplayer_8dHXJoZ3a4IGbGUu_1.png
# Corresponding result: geoguessr_result_singleplayer_8dHXJoZ3a4IGbGUu_1.json
# Max RGB variance: 291.5233939860167
# Too low max RGB variance: geoguessr_location_singleplayer_8kiRXVpkhVUAKkFB_0.png
# Corresponding result: geoguessr_result_singleplayer_8kiRXVpkhVUAKkFB_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8nHtxcPIMwWWo7YK_2.png
# Corresponding result: geoguessr_result_singleplayer_8nHtxcPIMwWWo7YK_2.json
# Max RGB variance: 1.892895861967375
# Too low max RGB variance: geoguessr_location_singleplayer_8qUobrC6wvaWBNWs_0.png
# Corresponding result: geoguessr_result_singleplayer_8qUobrC6wvaWBNWs_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8sMh23QIUF5yhh1x_0.png
# Corresponding result: geoguessr_result_singleplayer_8sMh23QIUF5yhh1x_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_8tkdwskT7pPchIgx_0.png
# Corresponding result: geoguessr_result_singleplayer_8tkdwskT7pPchIgx_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_914TDLm0J9k3VkL4_0.png
# Corresponding result: geoguessr_result_singleplayer_914TDLm0J9k3VkL4_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_94y72t5lwJGMXTEZ_0.png
# Corresponding result: geoguessr_result_singleplayer_94y72t5lwJGMXTEZ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_98wzgpFAJ1VMsVCY_0.png
# Corresponding result: geoguessr_result_singleplayer_98wzgpFAJ1VMsVCY_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_997GXsAJ3jQ14xZg_0.png
# Corresponding result: geoguessr_result_singleplayer_997GXsAJ3jQ14xZg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_99SYIgoHfaxI2xiH_0.png
# Corresponding result: geoguessr_result_singleplayer_99SYIgoHfaxI2xiH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9E4sa266KGOAQPL1_0.png
# Corresponding result: geoguessr_result_singleplayer_9E4sa266KGOAQPL1_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9EffdOrwoB8nV1ZY_2.png
# Corresponding result: geoguessr_result_singleplayer_9EffdOrwoB8nV1ZY_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9Ex3tBYJQgEdsxKo_0.png
# Corresponding result: geoguessr_result_singleplayer_9Ex3tBYJQgEdsxKo_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9HoSxP0qtvGnG7XY_1.png
# Corresponding result: geoguessr_result_singleplayer_9HoSxP0qtvGnG7XY_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9IUHAAesZVHKUH1r_0.png
# Corresponding result: geoguessr_result_singleplayer_9IUHAAesZVHKUH1r_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9KlymQybErrzfhJZ_0.png
# Corresponding result: geoguessr_result_singleplayer_9KlymQybErrzfhJZ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9L1Hi7LoUbPCuKey_0.png
# Corresponding result: geoguessr_result_singleplayer_9L1Hi7LoUbPCuKey_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9Sql9T2UtjhN40Pv_0.png
# Corresponding result: geoguessr_result_singleplayer_9Sql9T2UtjhN40Pv_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9Vj8rorUfdIduexw_0.png
# Corresponding result: geoguessr_result_singleplayer_9Vj8rorUfdIduexw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9WyW0vf6yHRj1ZrJ_0.png
# Corresponding result: geoguessr_result_singleplayer_9WyW0vf6yHRj1ZrJ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9YWFtr4d4bPax8Cq_0.png
# Corresponding result: geoguessr_result_singleplayer_9YWFtr4d4bPax8Cq_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9a3NCiiASu55kzHx_0.png
# Corresponding result: geoguessr_result_singleplayer_9a3NCiiASu55kzHx_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9gsUvVlluaEHagL8_4.png
# Corresponding result: geoguessr_result_singleplayer_9gsUvVlluaEHagL8_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_9po13wXiLBymVkJw_0.png
# Corresponding result: geoguessr_result_singleplayer_9po13wXiLBymVkJw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_A2EAFoVnCbBqrO2H_0.png
# Corresponding result: geoguessr_result_singleplayer_A2EAFoVnCbBqrO2H_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_A5uP6lDjh37MQJOI_0.png
# Corresponding result: geoguessr_result_singleplayer_A5uP6lDjh37MQJOI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_A7lH1EKANhkW7vtf_0.png
# Corresponding result: geoguessr_result_singleplayer_A7lH1EKANhkW7vtf_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AAAtCMsSVTsvqA8m_0.png
# Corresponding result: geoguessr_result_singleplayer_AAAtCMsSVTsvqA8m_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ABcrzWiYkfUJFvCj_0.png
# Corresponding result: geoguessr_result_singleplayer_ABcrzWiYkfUJFvCj_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ADReds6rCgO8zOSs_0.png
# Corresponding result: geoguessr_result_singleplayer_ADReds6rCgO8zOSs_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AF3lpNb4PbLX3iOF_0.png
# Corresponding result: geoguessr_result_singleplayer_AF3lpNb4PbLX3iOF_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AHcedOhnklT31HMq_0.png
# Corresponding result: geoguessr_result_singleplayer_AHcedOhnklT31HMq_0.json
# Max RGB variance: 104.84745276293303
# Too low max RGB variance: geoguessr_location_singleplayer_AKVrIqxi9yvuHpd5_0.png
# Corresponding result: geoguessr_result_singleplayer_AKVrIqxi9yvuHpd5_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AN0fWQ6Y2KVxRRbr_4.png
# Corresponding result: geoguessr_result_singleplayer_AN0fWQ6Y2KVxRRbr_4.json
# Max RGB variance: 61.961364795502526
# Too low max RGB variance: geoguessr_location_singleplayer_AOta5KOTGuUT1Iz6_0.png
# Corresponding result: geoguessr_result_singleplayer_AOta5KOTGuUT1Iz6_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AS7RGCWccGV2SvvN_0.png
# Corresponding result: geoguessr_result_singleplayer_AS7RGCWccGV2SvvN_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AUeZWEYuMhK9ZEWu_0.png
# Corresponding result: geoguessr_result_singleplayer_AUeZWEYuMhK9ZEWu_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AZqugKl61gkMk91q_0.png
# Corresponding result: geoguessr_result_singleplayer_AZqugKl61gkMk91q_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AbO4ADIjS0L0R4kT_0.png
# Corresponding result: geoguessr_result_singleplayer_AbO4ADIjS0L0R4kT_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AbX4QyUls9JgIw5q_0.png
# Corresponding result: geoguessr_result_singleplayer_AbX4QyUls9JgIw5q_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AfGKEWmClGrHPeWx_0.png
# Corresponding result: geoguessr_result_singleplayer_AfGKEWmClGrHPeWx_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AlGKiSyuOHhZayPX_4.png
# Corresponding result: geoguessr_result_singleplayer_AlGKiSyuOHhZayPX_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AlSbAd2GgnY2xnSp_0.png
# Corresponding result: geoguessr_result_singleplayer_AlSbAd2GgnY2xnSp_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ApbiZqA2XzAJKOW9_0.png
# Corresponding result: geoguessr_result_singleplayer_ApbiZqA2XzAJKOW9_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Aq5asoIYwzhc7ZDl_0.png
# Corresponding result: geoguessr_result_singleplayer_Aq5asoIYwzhc7ZDl_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AqSIAdJuqhcVQScp_0.png
# Corresponding result: geoguessr_result_singleplayer_AqSIAdJuqhcVQScp_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Aqx38goxSal6isZU_0.png
# Corresponding result: geoguessr_result_singleplayer_Aqx38goxSal6isZU_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_At3olCBUUgSgbVAD_0.png
# Corresponding result: geoguessr_result_singleplayer_At3olCBUUgSgbVAD_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Aw7AnKlEilehI3TT_0.png
# Corresponding result: geoguessr_result_singleplayer_Aw7AnKlEilehI3TT_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AwJQylfrtUVC4UB8_0.png
# Corresponding result: geoguessr_result_singleplayer_AwJQylfrtUVC4UB8_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AxaJLxnqFZtNMTPc_0.png
# Corresponding result: geoguessr_result_singleplayer_AxaJLxnqFZtNMTPc_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_AyYoJlSNKy5lYvXN_0.png
# Corresponding result: geoguessr_result_singleplayer_AyYoJlSNKy5lYvXN_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B0KbHvwExyE0TjlH_0.png
# Corresponding result: geoguessr_result_singleplayer_B0KbHvwExyE0TjlH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B2SBQ6dBQwu5gcYH_0.png
# Corresponding result: geoguessr_result_singleplayer_B2SBQ6dBQwu5gcYH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B3DqWRqGDSjWlQZr_0.png
# Corresponding result: geoguessr_result_singleplayer_B3DqWRqGDSjWlQZr_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B8RFKDd7Zml9tH4k_3.png
# Corresponding result: geoguessr_result_singleplayer_B8RFKDd7Zml9tH4k_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B8aNlzCN3c6gpC70_0.png
# Corresponding result: geoguessr_result_singleplayer_B8aNlzCN3c6gpC70_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_B96hQp6XkfljhOSf_0.png
# Corresponding result: geoguessr_result_singleplayer_B96hQp6XkfljhOSf_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BJlKfxtroMLx5COL_0.png
# Corresponding result: geoguessr_result_singleplayer_BJlKfxtroMLx5COL_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BMSdK5LuXxch9wEG_0.png
# Corresponding result: geoguessr_result_singleplayer_BMSdK5LuXxch9wEG_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BOrHlP47TT3gW5iW_0.png
# Corresponding result: geoguessr_result_singleplayer_BOrHlP47TT3gW5iW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BUYANAiMyDwVlROJ_4.png
# Corresponding result: geoguessr_result_singleplayer_BUYANAiMyDwVlROJ_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BbYE3p5kHKpdBzga_0.png
# Corresponding result: geoguessr_result_singleplayer_BbYE3p5kHKpdBzga_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Bbz3gZ0WY1PkghpI_0.png
# Corresponding result: geoguessr_result_singleplayer_Bbz3gZ0WY1PkghpI_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Bg0kzByOslSG6e6X_0.png
# Corresponding result: geoguessr_result_singleplayer_Bg0kzByOslSG6e6X_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_Bp2FLR0MERD6Cjyp_0.png
# Corresponding result: geoguessr_result_singleplayer_Bp2FLR0MERD6Cjyp_0.json
# Max RGB variance: 0.0
# Too low laplacian variance: geoguessr_location_singleplayer_BqNNV7h1SMDlYl9Y_3.png
# Corresponding result: geoguessr_result_singleplayer_BqNNV7h1SMDlYl9Y_3.json
# Laplacian variance: 4.766168594360352
# Too low max RGB variance: geoguessr_location_singleplayer_BrQsgqZBTieciDcw_0.png
# Corresponding result: geoguessr_result_singleplayer_BrQsgqZBTieciDcw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BufKlQohlkL6jorW_0.png
# Corresponding result: geoguessr_result_singleplayer_BufKlQohlkL6jorW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BuhJvHYYpUC82eGt_0.png
# Corresponding result: geoguessr_result_singleplayer_BuhJvHYYpUC82eGt_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_BuzYtP5DI9YyHS5I_0.png
# Corresponding result: geoguessr_result_singleplayer_BuzYtP5DI9YyHS5I_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_C0tFsrN5D3PjbDK4_0.png
# Corresponding result: geoguessr_result_singleplayer_C0tFsrN5D3PjbDK4_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_C2GG4iIzpiOotpti_3.png
# Corresponding result: geoguessr_result_singleplayer_C2GG4iIzpiOotpti_3.json
# Max RGB variance: 30.883815895070608
# Too low max RGB variance: geoguessr_location_singleplayer_C80gID8oP3JB7jT0_0.png
# Corresponding result: geoguessr_result_singleplayer_C80gID8oP3JB7jT0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_CM6z9ioe2V0KorAD_0.png
# Corresponding result: geoguessr_result_singleplayer_CM6z9ioe2V0KorAD_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_CMShISOQq5FSWfg9_0.png
# Corresponding result: geoguessr_result_singleplayer_CMShISOQq5FSWfg9_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_CVW9Mt0YCx6xZaS5_0.png
# Corresponding result: geoguessr_result_singleplayer_CVW9Mt0YCx6xZaS5_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_CXDpLiTeyIVo0xuh_0.png
# Corresponding result: geoguessr_result_singleplayer_CXDpLiTeyIVo0xuh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_CZ8qxL6l69nyUI27_0.png
# Corresponding result: geoguessr_result_singleplayer_CZ8qxL6l69nyUI27_0.json
# Max RGB variance: 0.0
# ...
# Too low max RGB variance: geoguessr_location_singleplayer_y6ZaV4QiVvlJdpgw_0.png
# Corresponding result: geoguessr_result_singleplayer_y6ZaV4QiVvlJdpgw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_y6khbNt7xZcDcAzD_0.png
# Corresponding result: geoguessr_result_singleplayer_y6khbNt7xZcDcAzD_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_y79cecx6TVNlsUhW_0.png
# Corresponding result: geoguessr_result_singleplayer_y79cecx6TVNlsUhW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yAy7YBn99DWwVHOv_1.png
# Corresponding result: geoguessr_result_singleplayer_yAy7YBn99DWwVHOv_1.json
# Max RGB variance: 80.23335415577118
# Too low max RGB variance: geoguessr_location_singleplayer_yGbn0vIql82iIPrC_0.png
# Corresponding result: geoguessr_result_singleplayer_yGbn0vIql82iIPrC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yH9kc49UtBb45X1d_0.png
# Corresponding result: geoguessr_result_singleplayer_yH9kc49UtBb45X1d_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yHFoeRMRJ4pOJIgP_0.png
# Corresponding result: geoguessr_result_singleplayer_yHFoeRMRJ4pOJIgP_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yHYibDtyBzpOU6ff_0.png
# Corresponding result: geoguessr_result_singleplayer_yHYibDtyBzpOU6ff_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yHmblqaADoDf2tPM_4.png
# Corresponding result: geoguessr_result_singleplayer_yHmblqaADoDf2tPM_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yOG8mF4MZy4wWjm2_0.png
# Corresponding result: geoguessr_result_singleplayer_yOG8mF4MZy4wWjm2_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yQAIFOsFVAwMWmf3_0.png
# Corresponding result: geoguessr_result_singleplayer_yQAIFOsFVAwMWmf3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yQk4HLPZlRgbnLQG_0.png
# Corresponding result: geoguessr_result_singleplayer_yQk4HLPZlRgbnLQG_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yRhQroOGrQ6Yjcgr_4.png
# Corresponding result: geoguessr_result_singleplayer_yRhQroOGrQ6Yjcgr_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yRiEugfSGaFkXkv3_0.png
# Corresponding result: geoguessr_result_singleplayer_yRiEugfSGaFkXkv3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yS3WbKGELup2dLOz_0.png
# Corresponding result: geoguessr_result_singleplayer_yS3WbKGELup2dLOz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yUMhj1ul6bj1g9rR_0.png
# Corresponding result: geoguessr_result_singleplayer_yUMhj1ul6bj1g9rR_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yUiYuAEcxsfxTlH8_0.png
# Corresponding result: geoguessr_result_singleplayer_yUiYuAEcxsfxTlH8_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yV0r5TWIxgG55B79_0.png
# Corresponding result: geoguessr_result_singleplayer_yV0r5TWIxgG55B79_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yVg3iyj162DmltY9_0.png
# Corresponding result: geoguessr_result_singleplayer_yVg3iyj162DmltY9_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yWAvmIjtKrAAucx3_0.png
# Corresponding result: geoguessr_result_singleplayer_yWAvmIjtKrAAucx3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yX17uJBgdXlaRyeh_0.png
# Corresponding result: geoguessr_result_singleplayer_yX17uJBgdXlaRyeh_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yXgytRo1KBRV51bz_0.png
# Corresponding result: geoguessr_result_singleplayer_yXgytRo1KBRV51bz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yYJ9wUox9zjGYufw_0.png
# Corresponding result: geoguessr_result_singleplayer_yYJ9wUox9zjGYufw_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yZVle8Qk7mtP9Jxl_0.png
# Corresponding result: geoguessr_result_singleplayer_yZVle8Qk7mtP9Jxl_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yZWhQUziJUWF7UtN_3.png
# Corresponding result: geoguessr_result_singleplayer_yZWhQUziJUWF7UtN_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yZoWnvzZADbHetho_0.png
# Corresponding result: geoguessr_result_singleplayer_yZoWnvzZADbHetho_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yb6DJ2VzRYf4dzwe_0.png
# Corresponding result: geoguessr_result_singleplayer_yb6DJ2VzRYf4dzwe_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ybVXDQrv1OEtTxrj_0.png
# Corresponding result: geoguessr_result_singleplayer_ybVXDQrv1OEtTxrj_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ybnbxKPJ7D62pls1_2.png
# Corresponding result: geoguessr_result_singleplayer_ybnbxKPJ7D62pls1_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ycBhaDGCjabPSXeY_0.png
# Corresponding result: geoguessr_result_singleplayer_ycBhaDGCjabPSXeY_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ydxHNO665b05rmIV_0.png
# Corresponding result: geoguessr_result_singleplayer_ydxHNO665b05rmIV_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yhp2RCOxbTxVPlfp_0.png
# Corresponding result: geoguessr_result_singleplayer_yhp2RCOxbTxVPlfp_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yj0FKzhQ2ReZg1lS_3.png
# Corresponding result: geoguessr_result_singleplayer_yj0FKzhQ2ReZg1lS_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yjUEhygtYB9j3ThL_0.png
# Corresponding result: geoguessr_result_singleplayer_yjUEhygtYB9j3ThL_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yrGKsSPv9yBwQDMy_0.png
# Corresponding result: geoguessr_result_singleplayer_yrGKsSPv9yBwQDMy_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ys0RS2IXftWtN0YC_0.png
# Corresponding result: geoguessr_result_singleplayer_ys0RS2IXftWtN0YC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ysdXac5T4ArSWel0_0.png
# Corresponding result: geoguessr_result_singleplayer_ysdXac5T4ArSWel0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yvBHp1XkrnnmKxoE_0.png
# Corresponding result: geoguessr_result_singleplayer_yvBHp1XkrnnmKxoE_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yvXd4dkahF2Dghmt_0.png
# Corresponding result: geoguessr_result_singleplayer_yvXd4dkahF2Dghmt_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yxNLsflSHsDHt7ah_1.png
# Corresponding result: geoguessr_result_singleplayer_yxNLsflSHsDHt7ah_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_yy7ycQCraqVUr0BQ_0.png
# Corresponding result: geoguessr_result_singleplayer_yy7ycQCraqVUr0BQ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_z1MgfEela00aJK0a_0.png
# Corresponding result: geoguessr_result_singleplayer_z1MgfEela00aJK0a_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_z2L9DnS2QdKYvfvE_0.png
# Corresponding result: geoguessr_result_singleplayer_z2L9DnS2QdKYvfvE_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_z2L9DnS2QdKYvfvE_2.png
# Corresponding result: geoguessr_result_singleplayer_z2L9DnS2QdKYvfvE_2.json
# Max RGB variance: 6.701244116212312
# Too low max RGB variance: geoguessr_location_singleplayer_z7cCJfG5bi6Sk5JG_0.png
# Corresponding result: geoguessr_result_singleplayer_z7cCJfG5bi6Sk5JG_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_z8OkMtfNpew3hmal_0.png
# Corresponding result: geoguessr_result_singleplayer_z8OkMtfNpew3hmal_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_z8RjBfJxO5t1OMz3_0.png
# Corresponding result: geoguessr_result_singleplayer_z8RjBfJxO5t1OMz3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zCdkzgmHT3PolsuM_0.png
# Corresponding result: geoguessr_result_singleplayer_zCdkzgmHT3PolsuM_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zDzJn3RNBAcWjHHv_0.png
# Corresponding result: geoguessr_result_singleplayer_zDzJn3RNBAcWjHHv_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zErpAO4hKbibizr0_0.png
# Corresponding result: geoguessr_result_singleplayer_zErpAO4hKbibizr0_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zFDtolBBwdarTgsi_0.png
# Corresponding result: geoguessr_result_singleplayer_zFDtolBBwdarTgsi_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zFhisXrCnl1m80N5_0.png
# Corresponding result: geoguessr_result_singleplayer_zFhisXrCnl1m80N5_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zFmld50kkyqFQDuE_0.png
# Corresponding result: geoguessr_result_singleplayer_zFmld50kkyqFQDuE_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zHJCfZNT6WbRefFC_1.png
# Corresponding result: geoguessr_result_singleplayer_zHJCfZNT6WbRefFC_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zIHR7GQ2xCq6Js2X_0.png
# Corresponding result: geoguessr_result_singleplayer_zIHR7GQ2xCq6Js2X_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zK7fl234JmzYiPY1_0.png
# Corresponding result: geoguessr_result_singleplayer_zK7fl234JmzYiPY1_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zMNKidt0B09FiFvi_0.png
# Corresponding result: geoguessr_result_singleplayer_zMNKidt0B09FiFvi_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zNVDVmVh6YdUpXAg_0.png
# Corresponding result: geoguessr_result_singleplayer_zNVDVmVh6YdUpXAg_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zOXOur2ZvjuZdhIW_0.png
# Corresponding result: geoguessr_result_singleplayer_zOXOur2ZvjuZdhIW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zSpOUlwLzse0Dkui_0.png
# Corresponding result: geoguessr_result_singleplayer_zSpOUlwLzse0Dkui_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zWKeDOctLAVsfCle_1.png
# Corresponding result: geoguessr_result_singleplayer_zWKeDOctLAVsfCle_1.json
# Max RGB variance: 289.72456365262434
# Too low max RGB variance: geoguessr_location_singleplayer_zXgVnYzxMoBSvLad_2.png
# Corresponding result: geoguessr_result_singleplayer_zXgVnYzxMoBSvLad_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zYGucyFveslun8BX_4.png
# Corresponding result: geoguessr_result_singleplayer_zYGucyFveslun8BX_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zZ2XSpjibPUDiUKQ_0.png
# Corresponding result: geoguessr_result_singleplayer_zZ2XSpjibPUDiUKQ_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zaMxhxqGYh5eZ6r3_0.png
# Corresponding result: geoguessr_result_singleplayer_zaMxhxqGYh5eZ6r3_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zbcMZ84gDwFXhIn7_0.png
# Corresponding result: geoguessr_result_singleplayer_zbcMZ84gDwFXhIn7_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zcFS9K2w7AxoHY5L_0.png
# Corresponding result: geoguessr_result_singleplayer_zcFS9K2w7AxoHY5L_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zcHyw9KjzS5IM4u8_0.png
# Corresponding result: geoguessr_result_singleplayer_zcHyw9KjzS5IM4u8_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ze04XmbeeX8CKbWW_0.png
# Corresponding result: geoguessr_result_singleplayer_ze04XmbeeX8CKbWW_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zfMXzkOYO68urt6E_3.png
# Corresponding result: geoguessr_result_singleplayer_zfMXzkOYO68urt6E_3.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zgDMPyB4Q7JVD3aC_0.png
# Corresponding result: geoguessr_result_singleplayer_zgDMPyB4Q7JVD3aC_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zgxWrVh5UaVixHlV_0.png
# Corresponding result: geoguessr_result_singleplayer_zgxWrVh5UaVixHlV_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_ziSZTE09MJXsQm81_0.png
# Corresponding result: geoguessr_result_singleplayer_ziSZTE09MJXsQm81_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zjDfEytksCasCszz_0.png
# Corresponding result: geoguessr_result_singleplayer_zjDfEytksCasCszz_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zjN8PZMkdbgoeIF4_2.png
# Corresponding result: geoguessr_result_singleplayer_zjN8PZMkdbgoeIF4_2.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zkOR0D9z8WLbhejf_0.png
# Corresponding result: geoguessr_result_singleplayer_zkOR0D9z8WLbhejf_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zlieiYC3Wp4xLWlt_1.png
# Corresponding result: geoguessr_result_singleplayer_zlieiYC3Wp4xLWlt_1.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zmUeJykkj3QkyHCH_0.png
# Corresponding result: geoguessr_result_singleplayer_zmUeJykkj3QkyHCH_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_znV4M9LBbiOaN3eN_4.png
# Corresponding result: geoguessr_result_singleplayer_znV4M9LBbiOaN3eN_4.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zoo3O65QumPTC20l_0.png
# Corresponding result: geoguessr_result_singleplayer_zoo3O65QumPTC20l_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zutNSwCEQv7B5E89_0.png
# Corresponding result: geoguessr_result_singleplayer_zutNSwCEQv7B5E89_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zwSLXWKaLVxFHzo6_0.png
# Corresponding result: geoguessr_result_singleplayer_zwSLXWKaLVxFHzo6_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zxPuhhuNeGnXuMBi_0.png
# Corresponding result: geoguessr_result_singleplayer_zxPuhhuNeGnXuMBi_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zxao6cmA5cLLal9V_0.png
# Corresponding result: geoguessr_result_singleplayer_zxao6cmA5cLLal9V_0.json
# Max RGB variance: 0.0
# Too low max RGB variance: geoguessr_location_singleplayer_zyi73Qhz2LIMQvoX_3.png
# Corresponding result: geoguessr_result_singleplayer_zyi73Qhz2LIMQvoX_3.json
# Max RGB variance: 0.0
# 94490
# 81898
# 336411
# JSONDecodeError in geoguessr_result_singleplayer_nuaFyBKagRSNseUr_3.json
# Expecting value: line 1 column 1 (char 0)
# Duplicate locations: 528
# Duplicate locations more countries: 393
# Duplicate locations non mapped: 3624
# 93962
# 81505
# 332786
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Relevant files: 705681
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Relevant files: 705681
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 705681
# Relevant files: 705681
