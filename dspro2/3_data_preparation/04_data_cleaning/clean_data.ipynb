# %%
import json
import sys
import os
import cv2
import numpy as np
import concurrent

sys.path.insert(0, '../../')
from data_loader import get_data_to_load, load_json_files, update_data_to_load

MAX_VARIANCE_THRESHOLD = 300
LAPLACIAN_VARIANCE_THRESHOLD = 30
# Only enable if thresholds and filtering didn't change
USE_PREVIOUS = True

files = get_data_to_load(loading_file='../03_mapping/data_list', file_location='../01_enriching/.data/', image_file_location='../../1_data_collection/.data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
files_non_mapped = get_data_to_load(loading_file='./pre_filtering_data_list', file_location='../01_enriching/.data/', image_file_location='../../1_data_collection/.data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)

original_order = files.copy()
original_order_non_mapped = files_non_mapped.copy()

# sort files by file name
files.sort()
files_non_mapped.sort()

images = list(filter(lambda x: x.endswith('.png'), files))
images_non_mapped = list(filter(lambda x: x.endswith('.png'), files_non_mapped))
jsons = list(filter(lambda x: x.endswith('.json'), files))
jsons_non_mapped = list(filter(lambda x: x.endswith('.json'), files_non_mapped))

print(len(images))
print(len(images_non_mapped))

filtered_files = []
filtered_files_non_mapped = []

variance_map = {}
variance_map_non_mapped = {}

laplacian_variance_map = {}
laplacian_variance_map_non_mapped = {}

# pre load previous variance data if available
if USE_PREVIOUS:
  if os.path.exists('variance_map'):
    with open('variance_map', 'r', encoding='utf8') as f:
      variance_map = json.load(f)
  if os.path.exists('variance_map_non_mapped'):
    with open('variance_map_non_mapped', 'r', encoding='utf8') as f:
      variance_map_non_mapped = json.load(f)
  if os.path.exists('laplacian_variance_map'):
    with open('laplacian_variance_map', 'r', encoding='utf8') as f:
      laplacian_variance_map = json.load(f)
  if os.path.exists('laplacian_variance_map_non_mapped'):
    with open('laplacian_variance_map_non_mapped', 'r', encoding='utf8') as f:
      laplacian_variance_map_non_mapped = json.load(f)

# kernel to detect blurry images
laplacian_kernel = np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]])

def process_image(image_path, json_path):
  image = cv2.imread(image_path)
  try:
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  except OSError as e:
    print(e.strerror)
    if 'image file is truncated' in e.__repr__() or (e.strerror is not None and 'image file is truncated' in e.strerror):
      print("Image file is truncated. Skipping file: " + os.path.basename(image_path))
      return None
    print("Error reading image:", os.path.basename(image_path))
    print(e)
    return None
  except cv2.error as e:
    print("Error reading image:", os.path.basename(image_path))
    print(e)
    return None
  
  variance_colors = np.var(image, axis=(0, 1))
  
  max_variance = np.max(variance_colors)
  
  # get variance to detect blurry images, use grayscale image
  gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
  laplacian = cv2.filter2D(gray, cv2.CV_32F, laplacian_kernel)
  
  laplacian_variance = float(np.var(laplacian))
  
  return [image_path, json_path, max_variance, laplacian_variance]

def processAll(current_images, current_jsons, current_variance_map, current_laplacian_variance_map, current_filtered_files):
  def process_image_with_cache(image_path, json_path):
    image_basename = os.path.basename(image_path)
    
    if image_basename in current_variance_map:
      max_variance = current_variance_map[image_basename]
    else:
      max_variance = None
      
    if image_basename in current_laplacian_variance_map:
      laplacian_variance = current_laplacian_variance_map[image_basename]
    else:
      laplacian_variance = None
      
    if max_variance is None or laplacian_variance is None:
      result = process_image(image_path, json_path)
      if result is not None:
        image_path, json_path, max_variance, laplacian_variance = result
      
    return image_path, json_path, max_variance, laplacian_variance
    
  
  with concurrent.futures.ThreadPoolExecutor(max_workers=16) as executor:
    results = [executor.submit(process_image_with_cache, image_path, json_path) for image_path, json_path in zip(current_images, current_jsons)]
    
    for result in results:
      if result.result() is not None:
        image_path, json_path, max_variance, laplacian_variance = result.result()
        
        image_basename = os.path.basename(image_path)
        json_basename = os.path.basename(json_path)
        
        current_variance_map[image_basename] = max_variance
        current_laplacian_variance_map[image_basename] = laplacian_variance
        
        if max_variance > MAX_VARIANCE_THRESHOLD:
          if laplacian_variance > LAPLACIAN_VARIANCE_THRESHOLD:
            current_filtered_files.append(image_path)
            current_filtered_files.append(json_path)
          else:
            print("Too low laplacian variance:", image_basename)
            print("Corresponding result:", json_basename)
            print("Laplacian variance:", laplacian_variance)
        else:
          print("Too low max RGB variance:", image_basename)
          print("Corresponding result:", json_basename)
          print("Max RGB variance:", max_variance)
          
    current_filtered_images = list(filter(lambda x: x.endswith('.png'), current_filtered_files))
    
    return current_filtered_files, current_filtered_images
        
filtered_files, filtered_images = processAll(images, jsons, variance_map, laplacian_variance_map, filtered_files)

filtered_files_non_mapped, filtered_images_non_mapped = processAll(images_non_mapped, jsons_non_mapped, variance_map_non_mapped, laplacian_variance_map_non_mapped, filtered_files_non_mapped)
      
print(len(filtered_images))

print(len(filtered_images_non_mapped))

with open('variance_map', 'w', encoding='utf8') as f:
    json.dump(variance_map, f, ensure_ascii=False)
    
with open('variance_map_non_mapped', 'w', encoding='utf8') as f:
    json.dump(variance_map_non_mapped, f, ensure_ascii=False)
    
with open('laplacian_variance_map', 'w', encoding='utf8') as f:
    json.dump(laplacian_variance_map, f, ensure_ascii=False)
    
with open('laplacian_variance_map_non_mapped', 'w', encoding='utf8') as f:
    json.dump(laplacian_variance_map_non_mapped, f, ensure_ascii=False)
    
current_files = filtered_files.copy()
current_files_non_mapped = filtered_files_non_mapped.copy()

images = list(filter(lambda x: x.endswith('.png'), current_files))
images_non_mapped = list(filter(lambda x: x.endswith('.png'), current_files_non_mapped))
jsons = list(filter(lambda x: x.endswith('.json'), current_files))
jsons_non_mapped = list(filter(lambda x: x.endswith('.json'), current_files_non_mapped))

jsons_data = load_json_files(jsons, allow_err=True)
jsons_data_non_mapped = load_json_files(jsons_non_mapped, allow_err=True)

def remove_duplicates(current_images, current_jsons, current_jsons_data):
  current_filtered_files = []

  current_duplicate_locations = 0

  previous_locations = set()

  for image_path, json_path, json_data in zip(current_images, current_jsons, current_jsons_data):
    if json_data is None:
      continue
    # if they have the same coordinates, then they are the same location, only use the first
    str_coords = str(json_data['coordinates'])
    if str_coords in previous_locations:
      current_duplicate_locations += 1
      continue
    else:
      previous_locations.add(str_coords)
      current_filtered_files.append(image_path)
      current_filtered_files.append(json_path)
      
  return current_filtered_files, current_duplicate_locations

filtered_files, duplicate_locations = remove_duplicates(images, jsons, jsons_data)

print("Duplicate locations:", duplicate_locations)

filtered_files_non_mapped, duplicate_locations_non_mapped = remove_duplicates(images_non_mapped, jsons_non_mapped, jsons_data_non_mapped)

print("Duplicate locations non mapped:", duplicate_locations_non_mapped)

print(len(filtered_images))
print(len(filtered_images_non_mapped))

filtered_files_set = set(filtered_files)
filtered_files_non_mapped_set = set(filtered_files_non_mapped)
    
# Sort back to original order (some files were removed)
filtered_files = [file for file in original_order if file in filtered_files_set]
filtered_files_non_mapped = [file for file in original_order_non_mapped if file in filtered_files_non_mapped_set]

update_data_to_load(filtered_files, old_loading_file='../03_mapping/data_list', file_location='../01_enriching/data/', image_file_location='../../1_data_collection/data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
update_data_to_load(filtered_files_non_mapped, new_loading_file='./updated_data_list_non_mapped', old_loading_file='./pre_filtering_data_list', file_location='../01_enriching/data/', image_file_location='../../1_data_collection/data/', from_remote_only=True, download_link='default', allow_file_location_env=True, allow_image_file_location_env=True, allow_json_file_location_env=True, allow_download_link_env=True)
# Out:
# Warning: Skipping remote files check
# All local files: 666692
# Filtering out unpaired files
# Filtered out 66794 unpaired files
# Relevant files: 599898
# Warning: Skipping remote files check
# All local files: 666767
# Filtering out unpaired files
# Filtered out 66719 unpaired files
# Relevant files: 600048
# 299949
# 300024
# Using cached variance data for:Using cached variance data for: geoguessr_location_singleplayer_00AH3Et9ehwdPYL8_1.png
#  geoguessr_location_singleplayer_00AH3Et9ehwdPYL8_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00AH3Et9ehwdPYL8_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00AH3Et9ehwdPYL8_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00AH3Et9ehwdPYL8_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00BmGr2Li7T3U8lH_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00BmGr2Li7T3U8lH_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00BmGr2Li7T3U8lH_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00BmGr2Li7T3U8lH_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00DpE8W4ZSQnccDU_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00DpE8W4ZSQnccDU_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00DpE8W4ZSQnccDU_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00DpE8W4ZSQnccDU_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00MVtHYUJJ1JWFwB_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00MVtHYUJJ1JWFwB_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00kHTYU1WLrYNpgp_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00kHTYU1WLrYNpgp_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00kHTYU1WLrYNpgp_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00kHTYU1WLrYNpgp_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00klSlAsxSJFdx4p_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00klSlAsxSJFdx4p_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00klSlAsxSJFdx4p_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00klSlAsxSJFdx4p_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00klSlAsxSJFdx4p_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00nrQR2vDLCGkJKs_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00nrQR2vDLCGkJKs_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00nrQR2vDLCGkJKs_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00nrQR2vDLCGkJKs_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00nrQR2vDLCGkJKs_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAP67J3jZ3lh7j_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAP67J3jZ3lh7j_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAP67J3jZ3lh7j_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAP67J3jZ3lh7j_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAP67J3jZ3lh7j_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAkhgbKEznHj6y_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAkhgbKEznHj6y_1.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAkhgbKEznHj6y_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAkhgbKEznHj6y_3.png
# Using cached variance data for: geoguessr_location_singleplayer_00qAkhgbKEznHj6y_4.png
# Using cached variance data for: geoguessr_location_singleplayer_00riikZrPAPx5TTg_0.png
# Using cached variance data for: geoguessr_location_singleplayer_00riikZrPAPx5TTg_2.png
# Using cached variance data for: geoguessr_location_singleplayer_00riikZrPAPx5TTg_3.png
# Using cached variance data for: geoguessr_location_singleplayer_
3.png
# Using cached variance data for: geoguessr_location_singleplayer_05xuBTjDTlBt8P9q_4.png
# Using cached variance data for: geoguessr_location_singleplayer_05zOzrsJRw4lyz8K_0.png
# Using cached variance data for: geoguessr_location_singleplayer_05zOzrsJRw4lyz8K_1.png
# Using cached variance data for: geoguessr_location_singleplayer_05zOzrsJRw4lyz8K_2.png
# Using cached variance data for: geoguessr_location_singleplayer_05zOzrsJRw4lyz8K_3.png
# Using cached variance data for: geoguessr_location_singleplayer_05zOzrsJRw4lyz8K_4.png
# Using cached variance data for: geoguessr_location_singleplayer_060jfosXVyluLtDq_0.png
# Using cached variance data for: geoguessr_location_singleplayer_060jfosXVyluLtDq_1.png
# Using cached variance data for: geoguessr_location_singleplayer_060jfosXVyluLtDq_2.png
# Using cached variance data for: geoguessr_location_singleplayer_060jfosXVyluLtDq_3.png
# Using cached variance data for: geoguessr_location_singleplayer_063VKzezUT1X7Y6k_0.png
# Using cached variance data for: geoguessr_location_singleplayer_063VKzezUT1X7Y6k_1.png
# Using cached variance data for: geoguessr_location_singleplayer_063VKzezUT1X7Y6k_2.png
# Using cached variance data for: geoguessr_location_singleplayer_063VKzezUT1X7Y6k_3.png
# Using cached variance data for: geoguessr_location_singleplayer_063VKzezUT1X7Y6k_4.png
# Using cached variance data for: geoguessr_location_singleplayer_0673bwtcPMm5gjc5_0.png
# Using cached variance data for: geoguessr_location_singleplayer_0673bwtcPMm5gjc5_1.png
# Using cached variance data for: geoguessr_location_singleplayer_0673bwtcPMm5gjc5_2.png
# Using cached variance data for: geoguessr_location_singleplayer_0673bwtcPMm5gjc5_3.png
# Using cached variance data for: geoguessr_location_singleplayer_0673bwtcPMm5gjc5_4.png
# Using cached variance data for: geoguessr_location_singleplayer_068Spb79o4YsoT0c_0.png
# Using cached variance data for: geoguessr_location_singleplayer_068Spb79o4YsoT0c_1.png
# Using cached variance data for: geoguessr_location_singleplayer_068Spb79o4YsoT0c_2.png
# Using cached variance data for: geoguessr_location_singleplayer_068Spb79o4YsoT0c_3.png
# Using cached variance data for: geoguessr_location_singleplayer_06c1gJqL0ENcWL5A_0.png
# Using cached variance data for: geoguessr_location_singleplayer_06c1gJqL0ENcWL5A_1.png
# Using cached variance data for: geoguessr_location_singleplayer_06c1gJqL0ENcWL5A_2.png
# Using cached variance data for: geoguessr_location_singleplayer_06c1gJqL0ENcWL5A_3.png
# Using cached variance data for: geoguessr_location_singleplayer_06c1gJqL0ENcWL5A_4.png
# Using cached variance data for: geoguessr_location_singleplayer_06ms28lSCSO1xqDQ_0.png
# Using cached variance data for: geoguessr_location_singleplayer_06ms28lSCSO1xqDQ_2.png
# Using cached variance data for: geoguessr_location_singleplayer_06ms28lSCSO1xqDQ_3.png
# Using cached variance data for: geoguessr_location_singleplayer_06ms28lSCSO1xqDQ_4.png
# Using cached variance data for: geoguessr_location_singleplayer
3.png
# Using cached variance data for: geoguessr_location_singleplayer_07f095dqjuE9PKZs_4.png
# Too low max RGB variance: geoguessr_location_singleplayer_00RUSiKypPGLhMjI_0.png
# Corresponding result: geoguessr_result_singleplayer_00RUSiKypPGLhMjI_0.json
# Max RGB variance: 0.0
# Too low laplacian variance: geoguessr_location_singleplayer_022GFHWoXq5ZEP4f_4.png
# Corresponding result: geoguessr_result_singleplayer_022GFHWoXq5ZEP4f_4.json
# Laplacian variance: 6.321262359619141
# Too low max RGB variance: geoguessr_location_singleplayer_02ZYtmEyL505XW2a_0.png
# Corresponding result: geoguessr_result_singleplayer_02ZYtmEyL505XW2a_0.json
# Max RGB variance: 0.0
# Using cached variance data for: geoguessr_location_singleplayer_07jiBHcjPKsKTs2W_0.png
# Using cached variance data for: geoguessr_location_singleplayer_07jiBHcjPKsKTs2W_1.png
# Using cached variance data for: geoguessr_location_singleplayer_07jiBHcjPKsKTs2W_2.png
# Using cached variance data for: geoguessr_location_singleplayer_07jiBHcjPKsKTs2W_3.png
# Using cached variance data for: geoguessr_location_singleplayer_07jiBHcjPKsKTs2W_4.png
# Using cached variance data for: geoguessr_location_singleplayer_07munz66BQ2snEcd_0.png
# Using cached variance data for: geoguessr_location_singleplayer_07munz66BQ2snEcd_1.png
# Using cached variance data for: geoguessr_location_singleplayer_07munz66BQ2snEcd_2.png
# Using cached variance data for: geoguessr_location_singleplayer_07munz66BQ2snEcd_3.png
# Using cached variance data for: geoguessr_location_singleplayer_07munz66BQ2snEcd_4.png
# Using cached variance data for: geoguessr_location_singleplayer_07naZscj3PO3ufum_0.png
# Using cached variance data for: geoguessr_location_singleplayer_07naZscj3PO3ufum_1.png
# Using cached variance data for: geoguessr_location_singleplayer_07naZscj3PO3ufum_2.png
# Using cached variance data for: geoguessr_location_singleplayer_07naZscj3PO3ufum_3.png
# Using cached variance data for: geoguessr_location_singleplayer_07naZscj3PO3ufum_4.png
# Using cached variance data for: geoguessr_location_singleplayer_07nwpMTW93f7xdiX_0.png
# Using cached variance data for: geoguessr_location_singleplayer_07nwpMTW93f7xdiX_2.png
# Using cached variance data for: geoguessr_location_singleplayer_07nwpMTW93f7xdiX_3.png
# Using cached variance data for: geoguessr_location_singleplayer_07nwpMTW93f7xdiX_4.png
# Using cached variance data for: geoguessr_location_singleplayer_07xymkgXzwSrocJk_0.png
# Using cached variance data for: geoguessr_location_singleplayer_07xymkgXzwSrocJk_1.png
# Using cached variance data for: geoguessr_location_singleplayer_07xymkgXzwSrocJk_2.png
# Using cached variance data for: geoguessr_location_singleplayer_07xymkgXzwSrocJk_3.png
# Using cached variance data for: geoguessr_location_singleplayer_07xymkgXzwSrocJk_4.png
# Using cached variance data for: geoguessr_location_singleplayer_08080rhAnOfJDizg_0.png
# Using cached variance data for: geoguessr_location_singleplayer_08080rhAnOfJDizg_1.png
# Using cached variance data for: geoguessr_location_singleplayer_08080rhAnOfJDizg_2.png
# Using cached variance data for: geoguessr_location_singleplayer_08080rhAnOfJDizg_3.png
# Using cached variance data for: geoguessr_location_singleplayer_089jDroPQR3t2qqF_0.png
# Using cached variance data for: geoguessr_location_singleplayer_089jDroPQR3t2qqF_1.png
# ...
# Using cached variance data for: geoguessr_location_singleplayer_BgmIndPk2squAhIg_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bgvw2D6il4pbnQQa_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bgvw2D6il4pbnQQa_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BhURlmzJM5KJJuGd_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BhWR4WAOIt3SmgVh_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BhWR4WAOIt3SmgVh_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BhWR4WAOIt3SmgVh_4.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhf64j5G9tHYXhiD_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhf64j5G9tHYXhiD_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhf64j5G9tHYXhiD_4.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhm9KDpmbLtNrOaO_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhm9KDpmbLtNrOaO_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BhoB2faWmi2D5Nul_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BhuBFKjqbm4MxdS1_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BhuBFKjqbm4MxdS1_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BhuBFKjqbm4MxdS1_4.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhw0QXx72gLSqZxM_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhw0QXx72gLSqZxM_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bhw0QXx72gLSqZxM_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BhwkuuzkWetxgfkj_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BhwkuuzkWetxgfkj_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BhwkuuzkWetxgfkj_4.png
# Using cached variance data for: geoguessr_location_singleplayer_Bi1V1clBXLd0TTNz_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bi1V1clBXLd0TTNz_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bi4HbTDP0VogYEsV_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bi4HbTDP0VogYEsV_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bi4HbTDP0VogYEsV_4.png
# Using cached variance data for: geoguessr_location_singleplayer_
0.png
# Using cached variance data for: geoguessr_location_singleplayer_BktjDbku3LxsDhVT_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BktjDbku3LxsDhVT_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BktjDbku3LxsDhVT_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BktjDbku3LxsDhVT_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BkuK4exHbuqieY1u_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BkuK4exHbuqieY1u_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BkuK4exHbuqieY1u_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BkuK4exHbuqieY1u_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BkvS4P7HeohTGCPl_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BkvS4P7HeohTGCPl_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bkx8NYq5tVvIFkGR_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bkx8NYq5tVvIFkGR_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bky1QiLCQojboXWO_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bky1QiLCQojboXWO_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bky1QiLCQojboXWO_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bky1QiLCQojboXWO_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bl6VYImmaYAWWKPL_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bl6VYImmaYAWWKPL_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bl90QMgoatA5aNoZ_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bl90QMgoatA5aNoZ_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bl90QMgoatA5aNoZ_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlIw5E3Ka6AFNdTg_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlQMNXdxi3RY1NNA_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BlR2OHd9ab5xS4Nc_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlR2OHd9ab5xS4Nc_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlRz1me8vOD8FM7n_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BlRz1me8vOD8FM7n_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlhNKDFRMJJHwqbw_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BlhNKDFRMJJHwqbw_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BlhNKDFRMJJHwqbw_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlikvGwdgLOQGU8I_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BlikvGwdgLOQGU8I_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BlikvGwdgLOQGU8I_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlnhKQIUbg3o5Ndp_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlnhKQIUbg3o5Ndp_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlqwJi8GUQqLAgzs_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BlqwJi8GUQqLAgzs_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BlqwJi8GUQqLAgzs_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BluVxqRaW6FvzYig_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BluVxqRaW6FvzYig_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlxZTvDaMkpK4erS_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BlxZTvDaMkpK4erS_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BlxZTvDaMkpK4erS_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BlzNwPI4w7qFXBSx_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BlzNwPI4w7qFXBSx_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BlzNwPI4w7qFXBSx_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BlzNwPI4w7qFXBSx_4.png
# Using cached variance data for:Using cached variance data for: geoguessr_location_singleplayer_Bm2oG4D78ufLLUbT_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm2oG4D78ufLLUbT_4.png
#  geoguessr_location_singleplayer_Bm2oG4D78ufLLUbT_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm5HastQz1rlYuU1_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm5HastQz1rlYuU1_2.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm5HastQz1rlYuU1_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm8MJU5ASOuweztE_0.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm8MJU5ASOuweztE_1.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm8MJU5ASOuweztE_3.png
# Using cached variance data for: geoguessr_location_singleplayer_Bm8MJU5ASOuweztE_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BmAcBdahU32qBFvl_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BmAcBdahU32qBFvl_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BmDRqUuvKJLLz8pZ_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BmDRqUuvKJLLz8pZ_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BmDRqUuvKJLLz8pZ_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BmDRqUuvKJLLz8pZ_4.png
# Using cached variance data for: geoguessr_location_singleplayer_BmFCs4Iow91i2gH6_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BmFCs4Iow91i2gH6_2.png
# Using cached variance data for: geoguessr_location_singleplayer_BmFCs4Iow91i2gH6_3.png
# Using cached variance data for: geoguessr_location_singleplayer_BmGmYrNpQHsdw1JL_0.png
# Using cached variance data for: geoguessr_location_singleplayer_BmGmYrNpQHsdw1JL_1.png
# Using cached variance data for: geoguessr_location_singleplayer_BmGmYrNpQHsdw1JL_3.png
