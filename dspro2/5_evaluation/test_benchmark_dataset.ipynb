# %%
from PIL import Image, UnidentifiedImageError
import os
import re
import sys
import concurrent
import torch
import json
import requests
from torchvision import transforms
from image_data_handler_test import TestImageDataHandler
from geo_model_tester import GeoModelTester
from wandb_downloader import WandbDownloader
from custom_image_dataset_test import CustomImageDatasetTest

sys.path.insert(0, '../')
from data_loader import resolve_env_variable, load_image_file_raw, get_image_files

sys.path.insert(0, './4_modeling')
from region_handler import RegionHandler

# %%
test_data_path = "C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k"
print("Test data path: ", test_data_path)
image_path = os.path.join(test_data_path, "image_processed")
json_path = os.path.join(test_data_path, "jsons")
# Out:
# Test data path:  C:\Users\yutar\Documents\HSLU\Paper_data\yfcc4k

# %%
# Check if GPU is available
if torch.cuda.is_available():
    print("GPU is available.")
    
    # Print the name of the GPU
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    
    # Print the total and available memory
    total_memory = torch.cuda.get_device_properties(0).total_memory / 1e9  # Convert bytes to GB
    print(f"Total Memory: {total_memory:.2f} GB")

    allocated_memory = torch.cuda.memory_allocated(0) / 1e9  # Convert bytes to GB
    print(f"Allocated Memory: {allocated_memory:.2f} GB")

    cached_memory = torch.cuda.memory_reserved(0) / 1e9  # Convert bytes to GB
    print(f"Cached Memory: {cached_memory:.2f} GB")

    # Print other properties
    device_properties = torch.cuda.get_device_properties(0)
    print(f"CUDA Capability: {device_properties.major}.{device_properties.minor}")
    print(f"Multi-Processor Count: {device_properties.multi_processor_count}")
else:
    print("No GPU found.")
# Out:
# No GPU found.

# %%
# get all image files
image_files = [os.path.join(image_path, f) for f in os.listdir(image_path) if os.path.isfile(os.path.join(image_path, f))]
print("Number of image files: ", len(image_files))
json_files = [os.path.join(json_path, f) for f in os.listdir(json_path) if os.path.isfile(os.path.join(json_path, f))]
print("Number of json files: ", len(json_files))
# Out:
# Number of image files:  4536
# Number of json files:  4536

# %%
# check if all image files have a corresponding json file and vice versa by comparing the file names without the extension
image_file_names = [os.path.splitext(os.path.basename(f))[0] for f in image_files]
json_file_names = [os.path.splitext(os.path.basename(f))[0] for f in json_files]
image_file_names = set(image_file_names)
json_file_names = set(json_file_names)

# check if all image files have a corresponding json file
missing_json_files = image_file_names - json_file_names
if len(missing_json_files) > 0:
    print("Missing json files: ", missing_json_files)

# check if all json files have a corresponding image file
missing_image_files = json_file_names - image_file_names
if len(missing_image_files) > 0:
    print("Missing image files: ", missing_image_files)

# remove image files without a corresponding json file
image_files = [f for f in image_files if os.path.splitext(os.path.basename(f))[0] not in missing_json_files]

# remove json files without a corresponding image file
json_files = [f for f in json_files if os.path.splitext(os.path.basename(f))[0] not in missing_image_files]

# create a list of tuples with the image and the data inside corresponding json file "coordinates":, "country_name", "country_code", "regions", "is_in_region" as keys
data = []
image_list = []
coordinates_list = []
country_name_list = []
country_code_list = []
regions_list = []
is_in_region_list = []

for image_file in image_files:
    image_file_name = os.path.splitext(os.path.basename(image_file))[0]
    json_file = [f for f in json_files if os.path.splitext(os.path.basename(f))[0] == image_file_name]
    if len(json_file) == 1:
        json_file = json_file[0]
        with open(json_file, "r", encoding="utf-8") as f:
            json_data = json.load(f)
            data.append((image_file, json_data))
            image_list.append(image_file)
            coordinates_list.append(json_data["coordinates"])
            country_name_list.append(json_data["country_name"])
            country_code_list.append(json_data["country_code"])
            regions_list.append(json_data["regions"])
            is_in_region_list.append(json_data["is_in_region"])

print("Number of image files with json data: ", len(data), len(image_list), len(coordinates_list), len(country_name_list), len(country_code_list), len(regions_list), len(is_in_region_list)  )

# print first 5 entries
for i in range(5):
    print(data[i])
# Out:
# Number of image files with json data:  4536 4536 4536 4536 4536 4536 4536
# ('C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k\\image_processed\\10003206806.jpg', {'coordinates': [5.1962, 44.3857], 'country_name': 'France', 'country_code': 'FR', 'regions': [['France_Drôme_FRA-5288', 'POINT (5.173945 44.683623)'], ['France_Vaucluse_FRA-5352', 'POINT (5.180045 44.011459)'], ['France_Bouches-du-Rhône_FRA-5274', 'POINT (5.090141 43.549418)'], ['France_Ardèche_FRA-5267', 'POINT (4.42979 44.755635)'], ['France_Isère_FRA-5311', 'POINT (5.577282 45.265943)']], 'is_in_region': True})
# ('C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k\\image_processed\\10008911015.jpg', {'coordinates': [-73.266, 44.3543], 'country_name': 'United States', 'country_code': 'US', 'regions': [['United States_Vermont_USA-3540', 'POINT (-72.665394 44.075698)'], ['United States_New Hampshire_USA-3538', 'POINT (-71.57834 43.68971)'], ['United States_Massachusetts_USA-3513', 'POINT (-71.805476 42.257527)'], ['United States_New York_USA-3559', 'POINT (-75.689152 42.990248)'], ['United States_Connecticut_USA-3537', 'POINT (-72.728324 41.624189)']], 'is_in_region': True})
# ('C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k\\image_processed\\10008921046.jpg', {'coordinates': [-73.266, 44.3543], 'country_name': 'United States', 'country_code': 'US', 'regions': [['United States_Vermont_USA-3540', 'POINT (-72.665394 44.075698)'], ['United States_New Hampshire_USA-3538', 'POINT (-71.57834 43.68971)'], ['United States_Massachusetts_USA-3513', 'POINT (-71.805476 42.257527)'], ['United States_New York_USA-3559', 'POINT (-75.689152 42.990248)'], ['United States_Connecticut_USA-3537', 'POINT (-72.728324 41.624189)']], 'is_in_region': True})
# ('C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k\\image_processed\\10024082366.jpg', {'coordinates': [15.3656, 49.5506], 'country_name': 'Czechia', 'country_code': 'CZ', 'regions': [['Czechia_Vysočina_CZE-1594', 'POINT (15.681963 49.410985)'], ['Czechia_Pardubický_CZE-10373', 'POINT (16.181563 49.898147)'], ['Czechia_Středočeský_CZE-1596', 'POINT (14.542936 49.990844)'], ['Czechia_Královéhradecký_CZE-1598', 'POINT (15.86012 50.371014)'], ['Czechia_Jihočeský_CZE-1593', 'POINT (14.42716 49.086885)']], 'is_in_region': True})
# ('C:\\Users\\yutar\\Documents\\HSLU\\Paper_data\\yfcc4k\\image_processed\\10024265006.jpg', {'coordinates': [18.28, 62.9962], 'country_name': 'Sweden', 'country_code': 'SE', 'regions': [['Sweden_Västernorrland_SWE-191', 'POINT (17.278062 63.111613)'], ['Sweden_Västerbotten_SWE-192', 'POINT (17.835397 64.869426)'], ['Sweden_Gävleborg_SWE-178', 'POINT (16.303193 61.463957)'], ['Sweden_Uppsala_SWE-195', 'POINT (17.693353 60.04616)'], ['Finland_Eckerö_ALD-4812', 'POINT (19.588779 60.195151)']], 'is_in_region': False})

# %%
# create a list of region_names for each image
region_names = []
for regions in regions_list:
    region_names.append([region[0] for region in regions])

print("Number of region names: ", len(region_names))
# Out:
# Number of region names:  4536

# %%
running_device = "colab_L4"
image_size = [80, 130]
data_augmentation = "base_augmentation" # or "base_augmentation", "full_augmentation_v2"
predict_coordinates=False
predict_regions=True

if running_device == "colab_L4":
    # Run unmapped images with low image resolution
    USE_MAPPED = False

elif running_device == "colab_A100":
    # Run mapped images with high image resolution
    image_size = [180, 320]
    NUMBER_OF_FILES = 79000

# %%
prediction_type = "regions" if predict_regions else ("coordinates" if predict_coordinates else "countries")

train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

preprocessing_config = { 'data_augmentation': data_augmentation, 'height': image_size[0], 'width': image_size[1], 'train_ratio': train_ratio, 'val_ratio': val_ratio, 'test_ratio': test_ratio }

base_transform = transforms.Compose([
          transforms.Resize((image_size[0], image_size[1])),
        ])
augmented_transform = None
final_transform = transforms.Compose([
          transforms.ToTensor(),
          transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])

if data_augmentation == "full_augmentation_v2":
    base_transform = transforms.Compose([])
    augmented_transform = transforms.Compose([
        # Disabled because black bars really hurt the performance at this size (only for v2)
        # transforms.RandomPerspective(distortion_scale=0.75, p=0.5),  # Randomly apply perspective transformation
        transforms.RandomResizedCrop((image_size[0], image_size[1]), scale=(0.75, 1.0)),  # Randomly crop the image and resize it to the original size
        transforms.RandomRotation(10),          # Randomly rotate the image by up to 10 degrees, sadly also causes black borders
        transforms.ColorJitter(
            brightness=(0.5, 1.5),  # Randomly change brightness (lower limit to simulate night, upper limit for bright daylight)
            contrast=(0.5, 1.5),    # Randomly change contrast
            saturation=(0.5, 1.5),  # Randomly change saturation
            hue=(-0.1, 0.1)         # Randomly change hue
        )
    ])

# %%
test_transform=transforms.Compose([base_transform, final_transform])

def load_image_file(file):
  # channels, height, width is the pytorch convention
  with Image.open(file) as img:
    img = img.convert("RGB")
    img = test_transform(img)
    return img

# load mutliple .png files parallelized
def load_image_files(files, num_workers=16):
  with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
    results = list(executor.map(load_image_file, files))
  return results


# load all images
images_loaded_list = load_image_files(image_list)
print("Number of images loaded: ", len(images_loaded_list))
# Out:
# Number of images loaded:  4536

# %%
project_name = "predicting-coordinates" if predict_coordinates else ("predicting-region" if predict_regions else "predicting-country")
sweep_metric_name = "Validation Distance (km)" if predict_coordinates or predict_regions else "Validation Accuracy Top 1"

# %%
wandb_downloader = WandbDownloader(entity="nlp_ls", project=f"dspro2-{project_name}", data_augmentation=data_augmentation, input_image_size=image_size)

file_names_to_download = [".pth", ".json"]

run_data = wandb_downloader.get_and_collect_best_runs(sweep_metric_name, file_names_to_download)
# Out:
# Found 5 matching runs.

# %%
print(run_data)
# Out:
# {'Best Run 1': {'id': 'a46wv6x3', 'parameters': {'seed': 42, 'epochs': 50, 'optimizer': 'adamW', 'model_name': 'resnet50', 'mapped_data': True, 'dataset_size': 81505, 'weight_decay': 0.1, 'learning_rate': 0.001, 'predict_regions': True, 'input_image_size': [80, 130], 'data_augmentation': 'base_augmentation', 'different_regions': 4596, 'dataset_identifier': '63289b51067a4c6ede4c44c23a329d82ab4964ed43942794430a9b71ec685b5c', 'different_countries': 75, 'predict_coordinates': False}, 'metrics': {'Validation Distance (km)': 3724.32276090458, 'test_data_run_id': '3sq5pqyq', '_step': 13, 'Train Loss': 29.596859680230697, 'Train Accuracy Top 5': 0.974567507405395, 'Validation Accuracy Top 5': 0.16906938224648796, '_timestamp': 1719231807.0481946, 'Validation Loss': 68.43571333425159, 'Train Accuracy Top 3 Country': 0.957618354863022, 'Train Accuracy Top 5 Country': 0.9669254903335496, 'Validation Accuracy Top 1 Country': 0.2610882767928348, 'Validation Accuracy Top 3 Country': 0.3435372063063616, 'Validation Accuracy Top 5 Country': 0.3855591681491933, '_wandb': {'runtime': 2571}, 'Train Distance (km)': 27.60539136261069, 'Validation Accuracy Top 1': 0.05803324949389608, 'Validation Accuracy Top 3': 0.12459358321575364, '_runtime': 2387.952618598938, 'Train Accuracy Top 1': 0.7912642630536518, 'Train Accuracy Top 3': 0.946435770248716, 'Train Accuracy Top 1 Country': 0.9178307889155696}, 'files': {'wandb_manifest.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/artifact/920090126/wandb_manifest.json', 'best_model': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/best_model_checkpointmodel_resnet50_lr_0.001_opt_adamW_weightDecay_0.1_imgSize_[80, 130]_predict_coordinates_False.pth', 'country_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/country_to_index.json', 'region_index_to_country_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_country_index.json', 'region_index_to_middle_point.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_middle_point.json', 'region_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_to_index.json', 'wandb-metadata.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-metadata.json', 'wandb-summary.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-summary.json', 'test_data': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/3sq5pqyq/run-20240623_154103-3sq5pqyq/test_data.pth'}}, 'Best Run 2': {'id': 'mph5mid5', 'parameters': {'seed': 42, 'epochs': 50, 'optimizer': 'adamW', 'model_name': 'resnet50', 'mapped_data': True, 'dataset_size': 81505, 'weight_decay': 0.001, 'learning_rate': 0.001, 'predict_regions': True, 'input_image_size': [80, 130], 'data_augmentation': 'base_augmentation', 'different_regions': 4596, 'dataset_identifier': '63289b51067a4c6ede4c44c23a329d82ab4964ed43942794430a9b71ec685b5c', 'different_countries': 75, 'predict_coordinates': False}, 'metrics': {'Validation Distance (km)': 3660.4908937013984, 'test_data_run_id': '3sq5pqyq', '_runtime': 925.090990781784, 'Train Accuracy Top 3': 0.7420468687010324, 'Train Accuracy Top 1 Country': 0.7888454594850403, 'Train Accuracy Top 3 Country': 0.8752738681576779, 'Train Accuracy Top 5 Country': 0.9040365975496468, 'Validation Accuracy Top 3 Country': 0.372369793264217, '_step': 5, 'Validation Loss': 66.02258464601914, 'Train Accuracy Top 5': 0.8260740013671498, 'Validation Accuracy Top 1': 0.059996319244218145, 'Validation Accuracy Top 5 Country': 0.4239003742101712, 'Train Loss': 33.28554828766432, 'Train Distance (km)': 846.9858849693596, 'Train Accuracy Top 1': 0.5007273938267927, '_timestamp': 1719232930.3865497, 'Validation Accuracy Top 3': 0.135758542 ...

# %%
best_run = run_data["Best Run 1"]

print(best_run)

best_run_files = best_run["files"]
print(best_run_files)
# Out:
# {'id': 'a46wv6x3', 'parameters': {'seed': 42, 'epochs': 50, 'optimizer': 'adamW', 'model_name': 'resnet50', 'mapped_data': True, 'dataset_size': 81505, 'weight_decay': 0.1, 'learning_rate': 0.001, 'predict_regions': True, 'input_image_size': [80, 130], 'data_augmentation': 'base_augmentation', 'different_regions': 4596, 'dataset_identifier': '63289b51067a4c6ede4c44c23a329d82ab4964ed43942794430a9b71ec685b5c', 'different_countries': 75, 'predict_coordinates': False}, 'metrics': {'Validation Distance (km)': 3724.32276090458, 'test_data_run_id': '3sq5pqyq', '_step': 13, 'Train Loss': 29.596859680230697, 'Train Accuracy Top 5': 0.974567507405395, 'Validation Accuracy Top 5': 0.16906938224648796, '_timestamp': 1719231807.0481946, 'Validation Loss': 68.43571333425159, 'Train Accuracy Top 3 Country': 0.957618354863022, 'Train Accuracy Top 5 Country': 0.9669254903335496, 'Validation Accuracy Top 1 Country': 0.2610882767928348, 'Validation Accuracy Top 3 Country': 0.3435372063063616, 'Validation Accuracy Top 5 Country': 0.3855591681491933, '_wandb': {'runtime': 2571}, 'Train Distance (km)': 27.60539136261069, 'Validation Accuracy Top 1': 0.05803324949389608, 'Validation Accuracy Top 3': 0.12459358321575364, '_runtime': 2387.952618598938, 'Train Accuracy Top 1': 0.7912642630536518, 'Train Accuracy Top 3': 0.946435770248716, 'Train Accuracy Top 1 Country': 0.9178307889155696}, 'files': {'wandb_manifest.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/artifact/920090126/wandb_manifest.json', 'best_model': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/best_model_checkpointmodel_resnet50_lr_0.001_opt_adamW_weightDecay_0.1_imgSize_[80, 130]_predict_coordinates_False.pth', 'country_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/country_to_index.json', 'region_index_to_country_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_country_index.json', 'region_index_to_middle_point.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_middle_point.json', 'region_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_to_index.json', 'wandb-metadata.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-metadata.json', 'wandb-summary.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-summary.json', 'test_data': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/3sq5pqyq/run-20240623_154103-3sq5pqyq/test_data.pth'}}
# {'wandb_manifest.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/artifact/920090126/wandb_manifest.json', 'best_model': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/best_model_checkpointmodel_resnet50_lr_0.001_opt_adamW_weightDecay_0.1_imgSize_[80, 130]_predict_coordinates_False.pth', 'country_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/country_to_index.json', 'region_index_to_country_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_country_index.json', 'region_index_to_middle_point.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_middle_point.json', 'region_to_index.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_to_index.json', 'wandb-metadata.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-metadata.json', 'wandb-summary.json': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/wandb-summary.json', 'test_data': 'https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/3sq5pqyq/run-20240623_154103-3sq5pqyq/test_data.pth'}

# %%
# Download the json file using the url and return the json data
def download_json_file(url):
    print("Downloading json file from: ", url)
    response = requests.get(url)
    response.raise_for_status()
    respone_data = response.json()
    return respone_data

# %%
country_to_index_json = download_json_file(best_run_files["country_to_index.json"])

print(len(country_to_index_json))
print(country_to_index_json)

region_index_to_country_index_json = None
region_to_index_json = None
region_index_to_middle_point_json = None
if predict_regions:
  region_index_to_country_index_json = download_json_file(best_run_files["region_index_to_country_index.json"])

  print(len(region_index_to_country_index_json))
  print(region_index_to_country_index_json)

  region_to_index_json = download_json_file(best_run_files["region_to_index.json"])

  print(len(region_to_index_json))
  print(region_to_index_json)

  region_index_to_middle_point_json = download_json_file(best_run_files["region_index_to_middle_point.json"])

  print(len(region_index_to_middle_point_json))
  print(region_index_to_middle_point_json)
# Out:
# Downloading json file from:  https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/country_to_index.json
# 75
# {'Albania': 0, 'Argentina': 1, 'Australia': 2, 'Austria': 3, 'Bangladesh': 4, 'Belgium': 5, 'Bolivia, Plurinational State of': 6, 'Botswana': 7, 'Brazil': 8, 'Bulgaria': 9, 'Cambodia': 10, 'Canada': 11, 'Chile': 12, 'Colombia': 13, 'Croatia': 14, 'Czechia': 15, 'Denmark': 16, 'Dominican Republic': 17, 'Ecuador': 18, 'Estonia': 19, 'Eswatini': 20, 'Finland': 21, 'France': 22, 'Germany': 23, 'Ghana': 24, 'Greece': 25, 'Guatemala': 26, 'Hungary': 27, 'India': 28, 'Indonesia': 29, 'Ireland': 30, 'Israel': 31, 'Italy': 32, 'Japan': 33, 'Kenya': 34, 'Korea, Republic of': 35, 'Kyrgyzstan': 36, "Lao People's Democratic Republic": 37, 'Latvia': 38, 'Lesotho': 39, 'Lithuania': 40, 'Malaysia': 41, 'Malta': 42, 'Mexico': 43, 'Montenegro': 44, 'Netherlands': 45, 'New Zealand': 46, 'Nigeria': 47, 'North Macedonia': 48, 'Norway': 49, 'Peru': 50, 'Philippines': 51, 'Poland': 52, 'Portugal': 53, 'Romania': 54, 'Russian Federation': 55, 'Rwanda': 56, 'Senegal': 57, 'Serbia': 58, 'Singapore': 59, 'Slovakia': 60, 'Slovenia': 61, 'South Africa': 62, 'Spain': 63, 'Sri Lanka': 64, 'Sweden': 65, 'Switzerland': 66, 'Thailand': 67, 'Türkiye': 68, 'Uganda': 69, 'Ukraine': 70, 'United Arab Emirates': 71, 'United Kingdom': 72, 'United States': 73, 'Uruguay': 74}
# Downloading json file from:  https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_country_index.json
# 2676
# {'34': 0, '35': 0, '36': 0, '37': 0, '38': 0, '39': 0, '40': 0, '41': 0, '42': 0, '43': 0, '44': 0, '45': 0, '149': 1, '150': 1, '151': 1, '152': 1, '153': 1, '154': 1, '155': 1, '156': 1, '157': 1, '158': 1, '159': 1, '160': 1, '161': 1, '162': 1, '163': 1, '164': 1, '165': 1, '166': 1, '167': 1, '168': 1, '169': 1, '170': 1, '171': 1, '172': 1, '185': 2, '186': 2, '187': 2, '188': 2, '189': 2, '190': 2, '191': 2, '192': 2, '193': 2, '194': 2, '195': 2, '196': 2, '197': 3, '198': 3, '199': 3, '200': 3, '201': 3, '202': 3, '203': 3, '204': 3, '205': 3, '319': 4, '320': 4, '321': 4, '322': 4, '323': 4, '324': 4, '325': 4, '344': 5, '345': 5, '346': 5, '347': 5, '348': 5, '349': 5, '350': 5, '351': 5, '352': 5, '353': 5, '354': 5, '404': 6, '405': 6, '406': 6, '407': 6, '408': 6, '409': 6, '410': 6, '411': 6, '412': 6, '432': 7, '433': 7, '434': 7, '435': 7, '436': 7, '437': 7, '438': 7, '439': 7, '440': 7, '441': 7, '442': 7, '443': 7, '444': 7, '445': 7, '446': 7, '447': 8, '448': 8, '449': 8, '450': 8, '451': 8, '452': 8, '453': 8, '454': 8, '455': 8, '456': 8, '457': 8, '458': 8, '459': 8, '460': 8, '461': 8, '462': 8, '463': 8, '464': 8, '465': 8, '466': 8, '467': 8, '468': 8, '469': 8, '470': 8, '471': 8, '472': 8, '473': 8, '479': 9, '480': 9, '481': 9, '482': 9, '483': 9, '484': 9, '485': 9, '486': 9, '487': 9, '488': 9, '489': 9, '490': 9, '491': 9, '492': 9, '493': 9, '494': 9, '495': 9, '496': 9, '497': 9, '498': 9, '499': 9, '500': 9, '501': 9, '502': 9, '503': 9, '504': 9, '505': 9, '506': 9, '591': 10, '592': 10, '593': 10, '594': 10, '595': 10, '596': 10, '597': 10, '598': 10, '599': 10, '600': 10, '601': 10, '602': 10, '603': 10, '604': 10, '605': 10, '606': 10, '607': 10, '608': 10, '609': 10, '610': 10, '611': 10, '612': 10, '613': 10, '614': 10, '625': 11, '626': 11, '627': 11, '628': 11, '629': 11, '630': 11, '631': 11, '632': 11, '633': 11, '634': 11, '635': 11, '636': 11, '637': 11, '678': 12, '679': 12, '680': 12, '681': 12, '682': 12, '683': 12, '684': 12, '685': 12, '686': 12, '687': 12, '688': 12, '689': 12, '690': 12, '691': 12, '692': 12, '693': 12, '729': 13, '730': 13, '731': 13, '732': 13, '733': 13, '734': 13, '735': 13, '736': 13, '737': 13, '738': 13, '739': 13, '740': 13, '741': 13, '742': 13, '743': 13, '744': 13, '745': 13, '746': 13, '747': 13, '748': 13, '749': 13, '750': 13, '751': 13, '752': 13, '753': 13, '754': 13, '755': 13, '756': 13, '757': 13, '758': 13, '759': 13, '760': 13, '761': 13, '762': 13, '807': 14, '808': 14, '809': 14, '810': 14, '811': 14, '812': 14, '813': 14, '814': 14, '815': 14, '816': 14, '817': 14, '818': 14, '819': 14, '820': 14, '821': 14, '822': 14, '823': 14, '824': 14, '825': 14, '826': 14, '827': 14, '853': 15, '854': 15, '855': 15, '856': 15, '857': 15, '858': 15, '859': 15, '860': 15, '861': 15, '862': 15, '863': 15, '864': 15, '865': 15, '866': 15, '886': 16, '887': 16, '888': 16, '889': 16, '890': 16, '907': 17, '908': 17, '909': 17, '910': 17, '911': 17, '912': 17, '913': 17, '914': 17, '915': 17, '916': 17, '917': 17, '918': 17, '919': 17, '920': 17, '921': 17, '922': 17, '923': 17, '924': 17, '925': 17, '926': 17, '927': 17, '928': 17, '929': 17, '930': 17, '931': 17, '932': 17, '933': 17, '934': 17, '935': 17, '936': 17, '937': 17, '938': 17, '939': 18, '940': 18, '941': 18, '942': 18, '943': 18, '944': 18, '945': 18, '946': 18, '947': 18, '948': 18, '949': 18, '950': 18, '951': 18, '952': 18, '953': 18, '954': 18, '955': 18, '956': 18, '957': 18, '958': 18, '959': 18, '960': 18, '961': 18, '962': 18, '1017': 19, '1018': 19, '1019': 19, '1020': 19, '1021': 19, '1022': 19, '1023': 19, '1024': 19, '1025': 19, '1026': 19, '1027': 19, '1028': 19, '1029': 19, '1030': 19, '1031': 19, '1032': 20, '1033': 20, '1034': 20, '1035': 20, '1054': 21, '1055': 21, '1056': 21, '1057': 21, '1058': 21, '1059': 21, '1060': 21, '1061': 21, '1062': 21, '1063': 21, '1064': 21, '1065': 21, '1066': 21, '1067': 21, '1068': 21, '1069': 21, '1070': 21, '1071': 21, '1072': 21, '1 ...
# Downloading json file from:  https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_to_index.json
# 4596
# {'Afghanistan_Badakhshan_AFG-1760': 0, 'Afghanistan_Badghis_AFG-1741': 1, 'Afghanistan_Baghlan_AFG-1766': 2, 'Afghanistan_Balkh_AFG-1744': 3, 'Afghanistan_Bamyan_AFG-1743': 4, 'Afghanistan_Farah_AFG-1749': 5, 'Afghanistan_Faryab_AFG-1745': 6, 'Afghanistan_Ghazni_AFG-1757': 7, 'Afghanistan_Ghor_AFG-1747': 8, 'Afghanistan_Hilmand_AFG-1750': 9, 'Afghanistan_Hirat_AFG-1742': 10, 'Afghanistan_Jawzjan_AFG-1746': 11, 'Afghanistan_Kabul_AFG-1767': 12, 'Afghanistan_Kandahar_AFG-1754': 13, 'Afghanistan_Kapisa_AFG-1768': 14, 'Afghanistan_Khost_AFG-1758': 15, 'Afghanistan_Kunar_AFG-1762': 16, 'Afghanistan_Kunduz_AFG-1763': 17, 'Afghanistan_Laghman_AFG-1770': 18, 'Afghanistan_Logar_AFG-1771': 19, 'Afghanistan_Nangarhar_AFG-1764': 20, 'Afghanistan_Nimroz_AFG-1751': 21, 'Afghanistan_Nuristan_AFG-1761': 22, 'Afghanistan_Paktika_AFG-1759': 23, 'Afghanistan_Paktya_AFG-3413': 24, 'Afghanistan_Parwan_AFG-1769': 25, 'Afghanistan_Parwan_AFG-1772': 26, 'Afghanistan_Samangan_AFG-1773': 27, 'Afghanistan_Sari Pul_AFG-1748': 28, 'Afghanistan_Takhar_AFG-1765': 29, 'Afghanistan_Uruzgan_AFG-1752': 30, 'Afghanistan_Uruzgan_AFG-1753': 31, 'Afghanistan_Wardak_AFG-1774': 32, 'Afghanistan_Zabul_AFG-1755': 33, 'Albania_Berat_ALB-1523': 34, 'Albania_Dibër_ALB-1526': 35, 'Albania_Durrës_ALB-1494': 36, 'Albania_Elbasan_ALB-1524': 37, 'Albania_Fier_ALB-1495': 38, 'Albania_Gjirokastër_ALB-1525': 39, 'Albania_Korçë_ALB-1521': 40, 'Albania_Kukës_ALB-1502': 41, 'Albania_Lezhë_ALB-1528': 42, 'Albania_Shkodër_ALB-1498': 43, 'Albania_Tiranë_ALB-1529': 44, 'Albania_Vlorë_ALB-1504': 45, 'Algeria_Adrar_DZA-2143': 46, 'Algeria_Alger_DZA-2195': 47, 'Algeria_Annaba_DZA-2163': 48, 'Algeria_Aïn Defla_DZA-2199': 49, 'Algeria_Aïn Témouchent_DZA-2144': 50, 'Algeria_Batna_DZA-2216': 51, 'Algeria_Biskra_DZA-2211': 52, 'Algeria_Blida_DZA-2209': 53, 'Algeria_Bordj Bou Arréridj_DZA-2207': 54, 'Algeria_Bouira_DZA-2210': 55, 'Algeria_Boumerdès_DZA-2196': 56, 'Algeria_Béchar_DZA-2148': 57, 'Algeria_Béjaïa_DZA-2208': 58, 'Algeria_Chlef_DZA-2200': 59, 'Algeria_Constantine_DZA-2217': 60, 'Algeria_Djelfa_DZA-2212': 61, 'Algeria_El Bayadh_DZA-2190': 62, 'Algeria_El Oued_DZA-2191': 63, 'Algeria_El Tarf_DZA-2164': 64, 'Algeria_Ghardaïa_DZA-2192': 65, 'Algeria_Guelma_DZA-2218': 66, 'Algeria_Illizi_DZA-2188': 67, 'Algeria_Jijel_DZA-2165': 68, 'Algeria_Khenchela_DZA-2219': 69, 'Algeria_Laghouat_DZA-2193': 70, "Algeria_M'Sila_DZA-2214": 71, 'Algeria_Mascara_DZA-2201': 72, 'Algeria_Mila_DZA-2220': 73, 'Algeria_Mostaganem_DZA-2202': 74, 'Algeria_Médéa_DZA-2213': 75, 'Algeria_Naâma_DZA-2149': 76, 'Algeria_Oran_DZA-2145': 77, 'Algeria_Ouargla_DZA-2194': 78, 'Algeria_Oum el Bouaghi_DZA-2221': 79, 'Algeria_Relizane_DZA-2203': 80, 'Algeria_Saïda_DZA-2204': 81, 'Algeria_Sidi Bel Abbès_DZA-2146': 82, 'Algeria_Skikda_DZA-2166': 83, 'Algeria_Souk Ahras_DZA-2222': 84, 'Algeria_Sétif_DZA-2215': 85, 'Algeria_Tamanghasset_DZA-2189': 86, 'Algeria_Tiaret_DZA-2205': 87, 'Algeria_Tindouf_DZA-2150': 88, 'Algeria_Tipaza_DZA-2198': 89, 'Algeria_Tissemsilt_DZA-2206': 90, 'Algeria_Tizi Ouzou_DZA-2197': 91, 'Algeria_Tlemcen_DZA-2147': 92, 'Algeria_Tébessa_DZA-2223': 93, 'American Samoa_Eastern_ASM-4998': 94, "American Samoa_Manu's_ASM-4999": 95, 'American Samoa_Rose Atoll_ASM-5000': 96, "American Samoa_Swain's Island_ASM-5001": 97, 'American Samoa_Western_ASM-5002': 98, 'Andorra_Andorra la Vella_AND-4876': 99, 'Andorra_Canillo_AND-4879': 100, 'Andorra_Encamp_AND-4880': 101, 'Andorra_Escaldes-Engordany_AND-4881': 102, 'Andorra_La Massana_AND-4877': 103, 'Andorra_Ordino_AND-4878': 104, 'Andorra_Sant Julià de Lòria_AND-4882': 105, 'Angola_Bengo_AGO-1877': 106, 'Angola_Benguela_AGO-1887': 107, 'Angola_Bié_AGO-1886': 108, 'Angola_Cabinda_AGO-1885': 109, 'Angola_Cuando Cubango_AGO-1888': 110, 'Angola_Cuanza Norte_AGO-1878': 111, 'Angola_Cuanza Sul_AGO-1879': 112, 'Angola_Cunene_AGO-1889': 113, 'Angola_Huambo_AGO-1890': 114, 'Angola_Huíla_AGO-1891': 115, 'Angola_Luanda_AGO-1880': 116, 'Angola_Lunda Norte_AGO-1874': 117, 'Angola_Lunda ...
# Downloading json file from:  https://api.wandb.ai/files/nlp_ls/dspro2-predicting-region/a46wv6x3/run-20240624_114339-a46wv6x3/region_index_to_middle_point.json
# 4596
# {'0': [37.035682, 71.441168], '1': [35.145819, 63.738203], '2': [35.798778, 68.910879], '3': [36.681257, 67.092233], '4': [34.803255, 67.237533], '5': [32.603044, 62.283569], '6': [36.063752, 64.862813], '7': [33.316916, 67.807273], '8': [34.169274, 64.892311], '9': [31.123173, 64.043618], '10': [34.189676, 62.127844], '11': [36.82697, 65.84327], '12': [34.553839, 69.322396], '13': [31.045129, 65.707668], '14': [34.959681, 69.618789], '15': [33.358015, 69.833141], '16': [34.955869, 71.077996], '17': [36.845988, 68.741476], '18': [34.761921, 70.145358], '19': [34.014477, 69.169499], '20': [34.272878, 70.454078], '21': [30.813863, 62.339455], '22': [35.409363, 70.777811], '23': [32.479961, 68.734062], '24': [33.62653, 69.386635], '25': [35.440906, 69.786125], '26': [34.953928, 68.886549], '27': [35.976237, 67.70108], '28': [35.742106, 66.147825], '29': [36.702348, 69.771456], '30': [32.855631, 66.045518], '31': [33.735247, 66.166464], '32': [34.313889, 68.225945], '33': [32.207371, 67.14228], '34': [40.630075, 20.090411], '35': [41.603631, 20.227378], '36': [41.447698, 19.626378], '37': [41.049808, 20.188665], '38': [40.767667, 19.623028], '39': [40.218186, 20.167236], '40': [40.628878, 20.661042], '41': [42.194872, 20.22649], '42': [41.799569, 19.847879], '43': [42.172615, 19.707644], '44': [41.267338, 19.791699], '45': [40.158404, 19.795671], '46': [25.703585, -0.443128], '47': [36.724378, 3.090417], '48': [36.85893, 7.530105], '49': [36.176066, 2.080172], '50': [35.335109, -1.030831], '51': [35.427852, 5.883069], '52': [34.5022, 5.344496], '53': [36.526746, 2.999735], '54': [36.085273, 4.730866], '55': [36.27712, 3.849002], '56': [36.765474, 3.6832], '57': [30.146045, -2.559673], '58': [36.570385, 4.846781], '59': [36.232517, 1.260461], '60': [36.347293, 6.70924], '61': [34.332577, 3.550843], '62': [32.570439, 0.9414], '63': [33.222433, 6.957223], '64': [36.722264, 8.117478], '65': [31.162297, 3.117175], '66': [36.402211, 7.399147], '67': [26.795661, 8.353429], '68': [36.701491, 5.961302], '69': [34.974376, 6.999357], '70': [33.559921, 2.699189], '71': [35.300692, 4.2764], '72': [35.389594, 0.143033], '73': [36.294398, 6.158336], '74': [35.99256, 0.331803], '75': [35.973555, 2.93701], '76': [33.274457, -0.782387], '77': [35.629657, -0.632057], '78': [30.658124, 6.209051], '79': [35.847475, 7.081928], '80': [35.793638, 0.800795], '81': [34.593407, 0.171261], '82': [34.789479, -0.565931], '83': [36.781564, 6.812256], '84': [36.155775, 7.886955], '85': [36.134258, 5.465657], '86': [23.972826, 5.116536], '87': [34.957859, 1.51563], '88': [27.622506, -6.095668], '89': [36.543145, 2.31212], '90': [35.745807, 1.800488], '91': [36.679941, 4.223301], '92': [34.733678, -1.422383], '93': [35.005761, 7.810236], '94': [-14.276019, -170.657216], '95': [-14.234545, -169.513667], '96': [-14.525255, -168.165129], '97': [-11.057943, -171.079758], '98': [-14.325101, -170.757679], '99': [42.515382, 1.515481], '100': [42.584522, 1.658058], '101': [42.537281, 1.645058], '102': [42.495963, 1.588761], '103': [42.554071, 1.474055], '104': [42.608978, 1.52647], '105': [42.467892, 1.488736], '106': [-8.980296, 13.880099], '107': [-12.932641, 13.978723], '108': [-12.323821, 17.358274], '109': [-5.035054, 12.456856], '110': [-16.110117, 19.497646], '111': [-8.898841, 14.939332], '112': [-10.825703, 15.037089], '113': [-16.500549, 15.580144], '114': [-12.567268, 15.741115], '115': [-14.742068, 14.946515], '116': [-8.958464, 13.322222], '117': [-8.6063, 19.523121], '118': [-10.179141, 20.64902], '119': [-9.516442, 16.99285], '120': [-12.880899, 21.027244], '121': [-15.484353, 12.722507], '122': [-7.023052, 15.469946], '123': [-6.607462, 13.565769], '124': [18.194222, -63.088233], '125': [18.269751, -62.977169], '126': [18.210741, -63.067064], '127': [18.270917, -63.002068], '128': [18.224651, -63.065449], '129': [18.254917, -63.04103], '130': [18.217873, -63.082362], '131': [18.235189, -63.013946], '132': [18.204801, -63.100795], '133': [18.251307, -63.024 ...

# %%
dataset = CustomImageDatasetTest(images=images_loaded_list, coordinates=coordinates_list, countries=country_name_list, regions=region_names, region_to_index=region_to_index_json, country_to_index=country_to_index_json)

print("Dataset length: ", len(dataset))
# Out:
# Warning: The following countries are missing in the mapping: {'Bhutan', 'Turks and Caicos Islands', 'Guyana', 'Saint Pierre and Miquelon', 'Viet Nam', 'Saint Martin (French part)', 'Palestine, State of', 'Svalbard and Jan Mayen', 'Bosnia and Herzegovina', 'Egypt', 'Bonaire, Sint Eustatius and Saba', 'Dominica', 'Saudi Arabia', 'Aruba', 'Myanmar', 'Honduras', 'Kuwait', 'Hong Kong', 'Mongolia', 'Montserrat', 'Curaçao', 'Grenada', 'Haiti', 'Panama', "Korea, Democratic People's Republic of", 'Andorra', 'Qatar', 'Luxembourg', 'Gibraltar', 'Madagascar', 'Cuba', 'Faroe Islands', 'Namibia', 'Cyprus', 'New Caledonia', 'Zimbabwe', 'Cameroon', 'Cabo Verde', 'Tunisia', 'Nepal', 'Macao', 'Taiwan, Province of China', 'Maldives', 'Jordan', 'Sudan', 'Ethiopia', 'Georgia', 'Monaco', 'Somalia', 'Mauritius', 'Papua New Guinea', 'Costa Rica', 'Cayman Islands', 'Syrian Arab Republic', 'Nicaragua', 'Iceland', 'Malawi', 'Jamaica', 'Mali', 'Bahamas', 'Réunion', 'Sierra Leone', 'China', 'Tanzania, United Republic of', 'Armenia', 'Pakistan', 'Morocco', 'Belize', 'Zambia', 'Fiji', 'Gambia', 'Uzbekistan', 'Holy See (Vatican City State)'}
# Removing image at index 13 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 27 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 46 with country 'Palestine, State of' not in the country_to_index mapping.
# Removing image at index 56 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 58 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 68 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 89 with country 'Zimbabwe' not in the country_to_index mapping.
# Removing image at index 93 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 97 with country 'China' not in the country_to_index mapping.
# Removing image at index 99 with country 'Kuwait' not in the country_to_index mapping.
# Removing image at index 100 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 105 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 123 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 133 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 175 with country 'Bhutan' not in the country_to_index mapping.
# Removing image at index 185 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 190 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 195 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 219 with country 'Bahamas' not in the country_to_index mapping.
# Removing image at index 253 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 259 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 271 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 295 with country 'Grenada' not in the country_to_index mapping.
# Removing image at index 331 with country 'Macao' not in the country_to_index mapping.
# Removing image at index 338 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 341 with country 'Namibia' not in the country_to_index mapping.
# Removing image at index 361 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 365 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 367 with country 'China' not in the country_to_index mapping.
# Removing image at index 376 with country 'China' not in the country_to_index mapping.
# Removing image at index 412 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 424 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 428 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 455 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 460 with country 'Réunion' not in the country_to_index mapping.
# Removing image at index 482 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 483 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 486 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 508 with country 'Aruba' not in the country_to_index mapping.
# Removing image at index 518 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 520 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 524 with country 'Montserrat' not in the country_to_index mapping.
# Removing image at index 527 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 544 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 574 with country 'Palestine, State of' not in the country_to_index mapping.
# Removing image at index 577 with country 'China' not in the country_to_index mapping.
# Removing image at index 591 with country 'Honduras' not in the country_to_index mapping.
# Removing image at index 624 with country 'Cayman Islands' not in the country_to_index mapping.
# Removing image at index 626 with country 'China' not in the country_to_index mapping.
# Removing image at index 640 with country 'Aruba' not in the country_to_index mapping.
# Removing image at index 656 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 658 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 660 with country 'Andorra' not in the country_to_index mapping.
# Removing image at index 684 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 696 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 730 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 734 with country 'Syrian Arab Republic' not in the country_to_index mapping.
# Removing image at index 747 with country 'Holy See (Vatican City State)' not in the country_to_index mapping.
# Removing image at index 767 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 785 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 787 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 790 with country 'China' not in the country_to_index mapping.
# Removing image at index 803 with country 'Mauritius' not in the country_to_index mapping.
# Removing image at index 806 with country 'Luxembourg' not in the country_to_index mapping.
# Removing image at index 811 with country 'China' not in the country_to_index mapping.
# Removing image at index 840 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 855 with country 'Tunisia' not in the country_to_index mapping.
# Removing image at index 867 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 889 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 890 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 897 with country 'China' not in the country_to_index mapping.
# Removing image at index 905 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 909 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 917 with country 'Nicaragua' not in the country_to_index mapping.
# Removing image at index 929 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 932 with country 'China' not in the country_to_index mapping.
# Removing image at index 936 with country 'China' not in the country_to_index mapping.
# Removing image at index 945 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 960 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 968 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 981 with country 'China' not in the country_to_index mapping.
# Removing image at index 989 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1001 with country 'Pakistan' not in the country_to_index mapping.
# Removing image at index 1002 with country 'China' not in the country_to_index mapping.
# Removing image at index 1004 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1006 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1038 with country 'Nicaragua' not in the country_to_index mapping.
# Removing image at index 1040 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1043 with country 'Saint Pierre and Miquelon' not in the country_to_index mapping.
# Removing image at index 1058 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1074 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 1075 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1101 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1106 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1117 with country 'Macao' not in the country_to_index mapping.
# Removing image at index 1134 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1137 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1142 with country 'Sierra Leone' not in the country_to_index mapping.
# Removing image at index 1144 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1156 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1189 with country 'China' not in the country_to_index mapping.
# Removing image at index 1195 with country 'China' not in the country_to_index mapping.
# Removing image at index 1206 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 1210 with country 'China' not in the country_to_index mapping.
# Removing image at index 1246 with country 'Qatar' not in the country_to_index mapping.
# Removing image at index 1281 with country 'Honduras' not in the country_to_index mapping.
# Removing image at index 1295 with country 'Belize' not in the country_to_index mapping.
# Removing image at index 1312 with country 'Qatar' not in the country_to_index mapping.
# Removing image at index 1314 with country 'China' not in the country_to_index mapping.
# Removing image at index 1327 with country 'Bonaire, Sint Eustatius and Saba' not in the country_to_index mapping.
# Removing image at index 1332 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1354 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 1364 with country 'Svalbard and Jan Mayen' not in the country_to_index mapping.
# Removing image at index 1391 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1394 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 1413 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1419 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1421 with country 'China' not in the country_to_index mapping.
# Removing image at index 1422 with country 'China' not in the country_to_index mapping.
# Removing image at index 1430 with country 'Gibraltar' not in the country_to_index mapping.
# Removing image at index 1446 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 1466 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 1473 with country 'Maldives' not in the country_to_index mapping.
# Removing image at index 1490 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1493 with country 'Nicaragua' not in the country_to_index mapping.
# Removing image at index 1502 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1506 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1515 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1548 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 1560 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 1574 with country 'Andorra' not in the country_to_index mapping.
# Removing image at index 1587 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 1617 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1642 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1643 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1644 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1650 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1657 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 1673 with country 'China' not in the country_to_index mapping.
# Removing image at index 1693 with country 'China' not in the country_to_index mapping.
# Removing image at index 1695 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 1714 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1744 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1759 with country 'China' not in the country_to_index mapping.
# Removing image at index 1771 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1788 with country 'Somalia' not in the country_to_index mapping.
# Removing image at index 1829 with country 'China' not in the country_to_index mapping.
# Removing image at index 1831 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 1833 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1844 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1854 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1894 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1905 with country 'China' not in the country_to_index mapping.
# Removing image at index 1906 with country 'China' not in the country_to_index mapping.
# Removing image at index 1911 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 1917 with country 'China' not in the country_to_index mapping.
# Removing image at index 1928 with country 'Holy See (Vatican City State)' not in the country_to_index mapping.
# Removing image at index 1930 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1932 with country 'Dominica' not in the country_to_index mapping.
# Removing image at index 1943 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1952 with country 'China' not in the country_to_index mapping.
# Removing image at index 1972 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 1975 with country 'China' not in the country_to_index mapping.
# Removing image at index 1982 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 1989 with country 'China' not in the country_to_index mapping.
# Removing image at index 2001 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2005 with country 'Fiji' not in the country_to_index mapping.
# Removing image at index 2060 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 2068 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 2070 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 2083 with country 'Holy See (Vatican City State)' not in the country_to_index mapping.
# Removing image at index 2095 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 2140 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 2158 with country 'Gibraltar' not in the country_to_index mapping.
# Removing image at index 2166 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2192 with country 'Mongolia' not in the country_to_index mapping.
# Removing image at index 2204 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2219 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2220 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2221 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2222 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2223 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2224 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2225 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2227 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2228 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2229 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2230 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2232 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2233 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 2256 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 2264 with country 'China' not in the country_to_index mapping.
# Removing image at index 2278 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2291 with country 'Palestine, State of' not in the country_to_index mapping.
# Removing image at index 2298 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 2322 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2324 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2335 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2346 with country 'Jamaica' not in the country_to_index mapping.
# Removing image at index 2352 with country 'Mali' not in the country_to_index mapping.
# Removing image at index 2362 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2373 with country 'China' not in the country_to_index mapping.
# Removing image at index 2375 with country 'China' not in the country_to_index mapping.
# Removing image at index 2382 with country 'Papua New Guinea' not in the country_to_index mapping.
# Removing image at index 2387 with country 'Bahamas' not in the country_to_index mapping.
# Removing image at index 2392 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 2396 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2404 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2419 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2426 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 2437 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2439 with country 'Kuwait' not in the country_to_index mapping.
# Removing image at index 2440 with country 'Gambia' not in the country_to_index mapping.
# Removing image at index 2475 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2480 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 2487 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2526 with country 'Maldives' not in the country_to_index mapping.
# Removing image at index 2539 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2547 with country 'Andorra' not in the country_to_index mapping.
# Removing image at index 2555 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 2562 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 2576 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 2583 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2594 with country 'Maldives' not in the country_to_index mapping.
# Removing image at index 2620 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2626 with country 'Myanmar' not in the country_to_index mapping.
# Removing image at index 2635 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2647 with country 'Fiji' not in the country_to_index mapping.
# Removing image at index 2651 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 2660 with country 'Turks and Caicos Islands' not in the country_to_index mapping.
# Removing image at index 2667 with country 'China' not in the country_to_index mapping.
# Removing image at index 2669 with country 'Luxembourg' not in the country_to_index mapping.
# Removing image at index 2673 with country 'Holy See (Vatican City State)' not in the country_to_index mapping.
# Removing image at index 2698 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2706 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 2709 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2720 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2734 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 2749 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 2751 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 2783 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2793 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 2794 with country 'China' not in the country_to_index mapping.
# Removing image at index 2830 with country 'Cameroon' not in the country_to_index mapping.
# Removing image at index 2835 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2846 with country 'China' not in the country_to_index mapping.
# Removing image at index 2847 with country 'Kuwait' not in the country_to_index mapping.
# Removing image at index 2849 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 2850 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 2877 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2886 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2910 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2926 with country 'Papua New Guinea' not in the country_to_index mapping.
# Removing image at index 2928 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 2941 with country 'Zambia' not in the country_to_index mapping.
# Removing image at index 2959 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 2972 with country 'Bhutan' not in the country_to_index mapping.
# Removing image at index 2974 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 3003 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 3010 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 3014 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 3020 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 3021 with country 'China' not in the country_to_index mapping.
# Removing image at index 3025 with country 'China' not in the country_to_index mapping.
# Removing image at index 3034 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 3037 with country 'Palestine, State of' not in the country_to_index mapping.
# Removing image at index 3055 with country 'Saudi Arabia' not in the country_to_index mapping.
# Removing image at index 3062 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3067 with country 'Tunisia' not in the country_to_index mapping.
# Removing image at index 3077 with country 'Jordan' not in the country_to_index mapping.
# Removing image at index 3092 with country 'Palestine, State of' not in the country_to_index mapping.
# Removing image at index 3093 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3094 with country 'Bosnia and Herzegovina' not in the country_to_index mapping.
# Removing image at index 3115 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3125 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3135 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 3143 with country 'China' not in the country_to_index mapping.
# Removing image at index 3148 with country 'Haiti' not in the country_to_index mapping.
# Removing image at index 3151 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 3165 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3181 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 3182 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 3194 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3195 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3196 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 3209 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3218 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3221 with country 'China' not in the country_to_index mapping.
# Removing image at index 3226 with country 'China' not in the country_to_index mapping.
# Removing image at index 3231 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 3246 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3250 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 3251 with country 'China' not in the country_to_index mapping.
# Removing image at index 3257 with country 'Cayman Islands' not in the country_to_index mapping.
# Removing image at index 3268 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3298 with country 'Korea, Democratic People's Republic of' not in the country_to_index mapping.
# Removing image at index 3314 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3323 with country 'China' not in the country_to_index mapping.
# Removing image at index 3324 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3327 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3328 with country 'China' not in the country_to_index mapping.
# Removing image at index 3333 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 3334 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 3335 with country 'Costa Rica' not in the country_to_index mapping.
# Removing image at index 3343 with country 'Monaco' not in the country_to_index mapping.
# Removing image at index 3380 with country 'Qatar' not in the country_to_index mapping.
# Removing image at index 3381 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3409 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3411 with country 'China' not in the country_to_index mapping.
# Removing image at index 3419 with country 'Belize' not in the country_to_index mapping.
# Removing image at index 3425 with country 'New Caledonia' not in the country_to_index mapping.
# Removing image at index 3430 with country 'Cyprus' not in the country_to_index mapping.
# Removing image at index 3434 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3435 with country 'Maldives' not in the country_to_index mapping.
# Removing image at index 3457 with country 'Curaçao' not in the country_to_index mapping.
# Removing image at index 3472 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3478 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3491 with country 'Saint Martin (French part)' not in the country_to_index mapping.
# Removing image at index 3503 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3520 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3530 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3540 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3579 with country 'China' not in the country_to_index mapping.
# Removing image at index 3587 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3595 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 3603 with country 'Holy See (Vatican City State)' not in the country_to_index mapping.
# Removing image at index 3610 with country 'Bosnia and Herzegovina' not in the country_to_index mapping.
# Removing image at index 3613 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3621 with country 'Faroe Islands' not in the country_to_index mapping.
# Removing image at index 3625 with country 'Gibraltar' not in the country_to_index mapping.
# Removing image at index 3626 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3661 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3664 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 3669 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3694 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 3719 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 3756 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3764 with country 'China' not in the country_to_index mapping.
# Removing image at index 3792 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3799 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3800 with country 'Armenia' not in the country_to_index mapping.
# Removing image at index 3807 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3819 with country 'China' not in the country_to_index mapping.
# Removing image at index 3879 with country 'China' not in the country_to_index mapping.
# Removing image at index 3899 with country 'Georgia' not in the country_to_index mapping.
# Removing image at index 3901 with country 'Panama' not in the country_to_index mapping.
# Removing image at index 3903 with country 'Guyana' not in the country_to_index mapping.
# Removing image at index 3909 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3916 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 3918 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 3919 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 3923 with country 'Malawi' not in the country_to_index mapping.
# Removing image at index 3931 with country 'China' not in the country_to_index mapping.
# Removing image at index 3955 with country 'Mauritius' not in the country_to_index mapping.
# Removing image at index 3963 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 3966 with country 'Egypt' not in the country_to_index mapping.
# Removing image at index 3967 with country 'Cuba' not in the country_to_index mapping.
# Removing image at index 3976 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 3978 with country 'China' not in the country_to_index mapping.
# Removing image at index 3986 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 3988 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 4011 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 4018 with country 'Viet Nam' not in the country_to_index mapping.
# Removing image at index 4025 with country 'Guyana' not in the country_to_index mapping.
# Removing image at index 4026 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4027 with country 'Ethiopia' not in the country_to_index mapping.
# Removing image at index 4028 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4035 with country 'Sudan' not in the country_to_index mapping.
# Removing image at index 4037 with country 'Myanmar' not in the country_to_index mapping.
# Removing image at index 4049 with country 'China' not in the country_to_index mapping.
# Removing image at index 4054 with country 'Nicaragua' not in the country_to_index mapping.
# Removing image at index 4064 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4069 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4088 with country 'Morocco' not in the country_to_index mapping.
# Removing image at index 4093 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 4131 with country 'China' not in the country_to_index mapping.
# Removing image at index 4134 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 4135 with country 'Georgia' not in the country_to_index mapping.
# Removing image at index 4163 with country 'Monaco' not in the country_to_index mapping.
# Removing image at index 4177 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4192 with country 'Namibia' not in the country_to_index mapping.
# Removing image at index 4216 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 4217 with country 'Iceland' not in the country_to_index mapping.
# Removing image at index 4221 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 4256 with country 'Nepal' not in the country_to_index mapping.
# Removing image at index 4271 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4282 with country 'Hong Kong' not in the country_to_index mapping.
# Removing image at index 4284 with country 'Tunisia' not in the country_to_index mapping.
# Removing image at index 4289 with country 'Uzbekistan' not in the country_to_index mapping.
# Removing image at index 4294 with country 'Cabo Verde' not in the country_to_index mapping.
# Removing image at index 4357 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4366 with country 'China' not in the country_to_index mapping.
# Removing image at index 4374 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4377 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4379 with country 'Tanzania, United Republic of' not in the country_to_index mapping.
# Removing image at index 4381 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4383 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4394 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4413 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4429 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4438 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4441 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4452 with country 'Madagascar' not in the country_to_index mapping.
# Removing image at index 4469 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4485 with country 'Bonaire, Sint Eustatius and Saba' not in the country_to_index mapping.
# Removing image at index 4499 with country 'Taiwan, Province of China' not in the country_to_index mapping.
# Removing image at index 4522 with country 'Madagascar' not in the country_to_index mapping.
# Removing image at index 4525 with country 'China' not in the country_to_index mapping.
# Dataset length:  4128

# %%
test_dataloader = torch.utils.data.DataLoader(dataset, batch_size=400, shuffle=False)

print("Test dataloader length: ", len(test_dataloader))

num_classes = len(region_to_index_json) if predict_regions else 3 if predict_coordinates else len(country_to_index_json)

geo_model_tester = GeoModelTester(datasize=len(dataset), test_dataloader=test_dataloader, num_classes=num_classes, predict_coordinates=predict_coordinates, predict_regions=predict_regions, country_to_index=country_to_index_json, region_to_index=region_to_index_json, region_index_to_middle_point=region_index_to_middle_point_json, region_index_to_country_index=region_index_to_country_index_json)
# Out:
# Test dataloader length:  11

# %%
geo_model_tester.test(model_type=best_run["parameters"]["model_name"], model_path=best_run_files["best_model"])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to C:\Users\yutar/.cache\torch\hub\checkpoints\resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 58.7MB/s]
# c:\Users\yutar\Documents\HSLU\repos\dspro2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# c:\Users\yutar\Documents\HSLU\repos\dspro2\.venv\Lib\site-packages\sklearn\metrics\_classification.py:2466: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# Test Loss: 82.0763, Test Distance: 8436.3847, Test Top 1 Accuracy: 0.0022, Test Top 3 Accuracy: 0.0063, Test Top 5 Accuracy: 0.0094
# Test Top 1 Accuracy (Country): 0.0000, Test Top 3 Accuracy (Country): 0.0000, Test Top 5 Accuracy (Country): 0.0000
# Test Top 1 Balanced Accuracy: 0.0008, Test Top 1 Balanced Accuracy (Country): 0.0000
