# %% [markdown]
# ## Clone Project, save data locally on rumtime and train model

# %%
from google.colab import drive, userdata
import os

# Mount Google Drive
drive.mount('/content/drive')

# Prompt to enter the access token securely
ACCESS_TOKEN = userdata.get('access_token_gitlab')

# Store the token in an environment variable
os.environ['ACCESS_TOKEN'] = ACCESS_TOKEN

# Make File runnable and run it
# !chmod +x ./drive/MyDrive/setup_environ_and_train.sh
# !./drive/MyDrive/setup_environ_and_train.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1): Installing...
#   - Installing qtconsole (5.5.1): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing altair (5.3.0): Downloading... 40%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43): Installing...
#   - Installing gradio-client (0.16.4): Downloading... 80%
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 20%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 40%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1): Installing...
#   - Installing qtconsole (5.5.1): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1): Installing...
#   - Installing qtconsole (5.5.1): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1): Installing...
#   - Installing qtconsole (5.5.1): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Pending...
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 20%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Pending...
#   - Installing gradio-client (0.16.4): Downloading... 100%
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 20%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Pending...
#   - Installing gradio-client (0.16.4): Downloading... 100%
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 20%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Pending...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4): Downloading... 100%
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 20%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Pending...
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 63%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing qtconsole (5.5.1): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing gradio-client (0.16.4): Installing...
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Pending...
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4): Installing...
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing altair (5.3.0): Downloading... 50%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4): Installing...
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 70%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing qtconsole (5.5.1): Installing...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Installing...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 100%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Installing...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 100%
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 100%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Installing...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 100%
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 30%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Downloading... 100%
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1): Installing...
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 100%
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 100%
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Downloading... 100%
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Pending...
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Pending...
#   - Installing semantic-version (2.10.0): Installing...
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Pending...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Installing...
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Pending...
#   - Installing protobuf (4.25.3): Installing...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0): Installing...
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Installing...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing keras (3.3.2): Downloading... 40%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Installing...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 40%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Installing...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing altair (5.3.0): Downloading... 60%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 40%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3): Installing...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Pending...
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Pending...
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Pending...
#   - Installing setproctitle (1.3.3): Downloading... 100%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing setproctitle (1.3.3): Installing...
#   - Installing tenacity (8.2.3): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing tenacity (8.2.3): Downloading... 0%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing tenacity (8.2.3): Downloading... 0%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Downloading... 0%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing tenacity (8.2.3): Downloading... 100%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 40%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Downloading... 100%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing altair (5.3.0): Downloading... 70%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 40%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 0%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Downloading... 100%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Downloading... 100%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Downloading... 100%
#   - Installing tomlkit (0.12.0): Downloading... 0%
#   - Installing torch (2.3.0): Pending...
#   - Installing torch (2.3.0): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 100%
#   - Installing torch (2.3.0): Pending...
#   - Installing tomlkit (0.12.0): Downloading... 100%
#   - Installing torch (2.3.0): Pending...
#   - Installing tenacity (8.2.3): Installing...
#   - Installing tomlkit (0.12.0): Downloading... 100%
#   - Installing torch (2.3.0): Pending...
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Installing...
#   - Installing tomlkit (0.12.0): Downloading... 100%
#   - Installing torch (2.3.0): Pending...
#   - Installing keras (3.3.2): Downloading... 50%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3): Installing...
#   - Installing tomlkit (0.12.0): Downloading... 100%
#   - Installing torch (2.3.0): Pending...
#   - Installing torch (2.3.0): Pending...
#   - Installing tomlkit (0.12.0): Installing...
#   - Installing torch (2.3.0): Pending...
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing tomlkit (0.12.0): Installing...
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0): Installing...
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Pending...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0): Installing...
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Pending...
#   - Installing sentry-sdk (2.0.1): Downloading... 41%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0): Installing...
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Pending...
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Pending...
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 50%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 41%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Pending...
#   - Installing altair (5.3.0): Downloading... 80%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 50%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 41%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Pending...
#   - Installing xyzservices (2024.4.0): Downloading... 0%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 41%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 0%
#   - Installing keras (3.3.2): Downloading... 60%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Downloading... 41%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 0%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 0%
#   - Installing sentry-sdk (2.0.1): Downloading... 81%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 100%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 100%
#   - Installing sentry-sdk (2.0.1): Downloading... 100%
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Downloading... 100%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing sentry-sdk (2.0.1): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 60%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing altair (5.3.0): Downloading... 100%
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 60%
#   - Installing matplotlib (3.8.4): Downloading... 0%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1): Installing...
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Downloading... 0%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing xxhash (3.4.1): Downloading... 100%
#   - Installing xyzservices (2024.4.0): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing xyzservices (2024.4.0)
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing keras (3.3.2): Downloading... 80%
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 80%
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing altair (5.3.0): Installing...
#   - Installing appdirs (1.4.4)
#   - Installing branca (0.7.2)
#   - Installing docker-pycreds (0.4.0)
#   - Installing fastapi (0.111.0)
#   - Installing ffmpy (0.3.2): Preparing...
#   - Installing gitpython (3.1.43)
#   - Installing gradio-client (0.16.4)
#   - Installing importlib-resources (6.4.0)
#   - Installing ipywidgets (8.1.2)
#   - Installing jupyter-console (6.6.3)
#   - Installing keras (3.3.2): Downloading... 80%
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 10%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1): Installing...
#   - Installing xyzservices (2024.4.0)
#   - Installing xyzservices (2024.4.0)
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 0%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing keras (3.3.2): Downloading... 100%
#   - Installing matplotlib (3.8.4): Downloading... 6%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing matplotlib (3.8.4): Downloading... 10%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing matplotlib (3.8.4): Downloading... 10%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing keras (3.3.2): Installing...
#   - Installing matplotlib (3.8.4): Downloading... 10%
#   - Installing multiprocess (0.70.16)
#   - Installing notebook (7.1.2): Downloading... 20%
#   - Installing protobuf (4.25.3)
#   - Installing pyarrow (16.0.0): Downloading... 0%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
#   - Installing torch (2.3.0): Downloading... 0%
#   - Installing xxhash (3.4.1)
#   - Installing xyzservices (2024.4.0)
#   - Installing pyarrow (16.0.0): Downloading... 2%
#   - Installing pyarrow-hotfix (0.6)
#   - Installing pydub (0.25.1)
#   - Installing qtconsole (5.5.1)
#   - Installing ruff (0.4.4): Downloading... 10%
#   - Installing scipy (1.13.0): Downloading... 0%
#   - Installing semantic-version (2.10.0)
#   - Installing sentry-sdk (2.0.1)
#   - Installing setproctitle (1.3.3)
#   - Installing tenacity (8.2.3)
#   - Installing tomlkit (0.12.0)
# ...
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 60%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 50%
#   - Installing opencv-python (4.9.0.80): Downloading... 60%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 70%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 70%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 60%
#   - Installing opencv-python (4.9.0.80): Downloading... 70%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing jupyter (1.0.0)
#   - Installing kaleido (0.2.1): Downloading... 60%
#   - Installing opencv-python (4.9.0.80): Downloading... 70%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing gradio (4.31.4)
#   - Installing jupyter (1.0.0)
#   - Installing kaleido (0.2.1): Downloading... 60%
#   - Installing opencv-python (4.9.0.80): Downloading... 70%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 80%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 80%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 70%
#   - Installing opencv-python (4.9.0.80): Downloading... 80%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 90%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 90%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 80%
#   - Installing opencv-python (4.9.0.80): Downloading... 90%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 100%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 100%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 90%
#   - Installing opencv-python (4.9.0.80): Downloading... 100%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1): Preparing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing reverse-geocoder (1.5.1): Installing...
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Downloading... 100%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Downloading... 100%
#   - Installing opencv-python (4.9.0.80): Downloading... 100%
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Installing...
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80): Installing...
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1): Installing...
#   - Installing opencv-python (4.9.0.80): Installing...
#   - Installing plotly (5.21.0): Installing...
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing plotly (5.21.0)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80)
#   - Installing plotly (5.21.0)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing opencv-python (4.9.0.80)
#   - Installing plotly (5.21.0)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#   - Installing kaleido (0.2.1)
#   - Installing opencv-python (4.9.0.80)
#   - Installing plotly (5.21.0)
#   - Installing pycountry (23.12.11)
#   - Installing resnet (0.1)
#   - Installing resnet-pytorch (0.2.0)
#   - Installing reverse-geocoder (1.5.1)
#   - Installing torchvision (0.18.0)
#   - Installing uuid (1.30)
#   - Installing wandb (0.16.6)
#
# Installing the current project: dspro2 (0.1.0)Installing the current project: dspro2 (0.1.0)
# [NbConvertApp] Converting notebook dspro2/4_modeling/training_resnet_models.ipynb to script
# [NbConvertApp] Writing 8761 bytes to dspro2/4_modeling/temp_executed_notebook.py
# /content/dspro2/dspro2/4_modeling
# Tesla T4
# GPU is available.
# GPU is available.
# GPU Name: Tesla T4
# Total Memory: 15.84 GB
# Allocated Memory: 0.00 GB
# Cached Memory: 0.00 GB
# CUDA Capability: 7.5
# Multi-Processor Count: 40
# Getting files list from remote
# Got files list from remote
# Parsed files list from remote
# All remote files: 705681
# All local files: 0
# Relevant files: 705681
# Limited files: 150000
# Downloading 150000 files
# Downloaded 1000 files
# Downloaded 2000 files
# Downloaded 3000 files
# Downloaded 4000 files
# Downloaded 5000 files
# Downloaded 6000 files
# Downloaded 7000 files
# Downloaded 8000 files
# Downloaded 9000 files
# Downloaded 10000 files
# Downloaded 11000 files
# Downloaded 12000 files
# Downloaded 13000 files
# Downloaded 14000 files
# Downloaded 15000 files
# Downloaded 16000 files
# Downloaded 17000 files
# Downloaded 18000 files
# Downloaded 19000 files
# Downloaded 20000 files
# Downloaded 21000 files
# Downloaded 22000 files
# Downloaded 23000 files
# Downloaded 24000 files
# Downloaded 25000 files
# Downloaded 26000 files
# Downloaded 27000 files
# Downloaded 28000 files
# Downloaded 29000 files
# Downloaded 30000 files
# Downloaded 31000 files
# Downloaded 32000 files
# Downloaded 33000 files
# Downloaded 34000 files
# Downloaded 35000 files
# Downloaded 36000 files
# Downloaded 37000 files
# Downloaded 38000 files
# Downloaded 39000 files
# Downloaded 40000 files
# Downloaded 41000 files
# Downloaded 42000 files
# Downloaded 43000 files
# Downloaded 44000 files
# Downloaded 45000 files
# Downloaded 46000 files
# Downloaded 47000 files
# Downloaded 48000 files
# Downloaded 49000 files
# Downloaded 50000 files
# Downloaded 51000 files
# Downloaded 52000 files
# Downloaded 53000 files
# Downloaded 54000 files
# Downloaded 55000 files
# Downloaded 56000 files
# Downloaded 57000 files
# Downloaded 58000 files
# Downloaded 59000 files
# Downloaded 60000 files
# Downloaded 61000 files
# Downloaded 62000 files
# Downloaded 63000 files
# Downloaded 64000 files
# Downloaded 65000 files
# Downloaded 66000 files
# Downloaded 67000 files
# Downloaded 68000 files
# Downloaded 69000 files
# Downloaded 70000 files
# Downloaded 71000 files
# Downloaded 72000 files
# Downloaded 73000 files
# Downloaded 74000 files
# Downloaded 75000 files
# Downloaded 76000 files
# Downloaded 77000 files
# Downloaded 78000 files
# Downloaded 79000 files
# Downloaded 80000 files
# Downloaded 81000 files
# Downloaded 82000 files
# Downloaded 83000 files
# Downloaded 84000 files
# Downloaded 85000 files
# Downloaded 86000 files
# Downloaded 87000 files
# Downloaded 88000 files
# Downloaded 89000 files
# Downloaded 90000 files
# Downloaded 91000 files
# Downloaded 92000 files
# Downloaded 93000 files
# Downloaded 94000 files
# Downloaded 95000 files
# Downloaded 96000 files
# Downloaded 97000 files
# Downloaded 98000 files
# Downloaded 99000 files
# Downloaded 100000 files
# Downloaded 101000 files
# Downloaded 102000 files
# Downloaded 103000 files
# Downloaded 104000 files
# Downloaded 105000 files
# Downloaded 106000 files
# Downloaded 107000 files
# Downloaded 108000 files
# Downloaded 109000 files
# Downloaded 110000 files
# Downloaded 111000 files
# Downloaded 112000 files
# Downloaded 113000 files
# Downloaded 114000 files
# Downloaded 115000 files
# Downloaded 116000 files
# Downloaded 117000 files
# Downloaded 118000 files
# Downloaded 119000 files
# Downloaded 120000 files
# Downloaded 121000 files
# Downloaded 122000 files
# Downloaded 123000 files
# Downloaded 124000 files
# Downloaded 125000 files
# Downloaded 126000 files
# Downloaded 127000 files
# Downloaded 128000 files
# Downloaded 129000 files
# Downloaded 130000 files
# Downloaded 131000 files
# Downloaded 132000 files
# Downloaded 133000 files
# Downloaded 134000 files
# Downloaded 135000 files
# Downloaded 136000 files
# Downloaded 137000 files
# Downloaded 138000 files
# Downloaded 139000 files
# Downloaded 140000 files
# Downloaded 141000 files
# Downloaded 142000 files
# Downloaded 143000 files
# Downloaded 144000 files
# Downloaded 145000 files
# Downloaded 146000 files
# Downloaded 147000 files
# Downloaded 148000 files
# Downloaded 149000 files
# Downloaded 150000 files
# Total non-corrupted pairs: 75000
# Loading images and labels:  95% 712/750 [04:40<00:15,  2.41it/s]
